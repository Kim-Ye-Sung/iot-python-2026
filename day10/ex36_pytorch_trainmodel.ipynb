# %% [markdown]
# ## 저장한 모델 사용하기

# %% [markdown]
# ### 라이브러리 로드

# %%
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim

import requests
from PIL import Image
from io import BytesIO
import os
import random
import shutil

# 사전학습 모델 라이브러리 추가 
from torchvision.models import resnet18, ResNet18_Weights
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder

# pip install icrawler
from icrawler.builtin import BingImageCrawler, BaiduImageCrawler

import matplotlib.pyplot as plt

# %%
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.version.cuda)
print(torch.cuda.get_device_name(0))
# Out:
# 2.12.0+cu130
# True
# 13.0
# NVIDIA GeForce RTX 5060

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### 2. 설정

# %%
model_path = 'resnet18_bird,_cat_dog.pth'
test_dir = 'dataset/test'

num_classes = 3
batch_size = 16

# %% [markdown]
# ### 3. ResNet18 모델구조 재생성

# %%
weight = ResNet18_Weights.DEFAULT
model = resnet18(weights = weight)

model.fc = nn.Linear(
    in_features=model.fc.in_features,
    out_features=num_classes
)

model = model.to(device=device)

# %% [markdown]
# ### 4. pth 모델파일 로드

# %%
model.load_state_dict(
    torch.load(model_path, map_location=device)
)

model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=3, bias=True)
# )

# %% [markdown]
# ### 5. 전처리 설정

# %%
preprocess = weight.transforms()
preprocess
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %% [markdown]
# ### 6. 바이두 이미지크롤링
#
# - 테스트 이미지셋 다운로드

# %%
# 추가설정
testset_dir = 'dataset/test'

classes = {
    'dog photo': 'dog',
    'cat photo': 'cat',
    'bird photo': 'bird'
}

num_epoch = 5
lr = 0.001

# %%
# 테스트이미지 폴더
for keyword, class_name in classes.items():
    save_dir = os.path.join(testset_dir, class_name)
    os.makedirs(save_dir, exist_ok=True)

    crawler = BaiduImageCrawler(
        storage={'root_dir': save_dir}
    )

    crawler.crawl(
        keyword=keyword,
        max_num=150
    )
# Out:
# 2026-05-21 15:56:49,668 - INFO - icrawler.crawler - start crawling...
# 2026-05-21 15:56:49,669 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-05-21 15:56:49,670 - INFO - feeder - thread feeder-001 exit
# 2026-05-21 15:56:49,671 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-05-21 15:56:49,672 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-05-21 15:56:51,729 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=dog photo&pn=0&rn=30
# 2026-05-21 15:56:51,732 - INFO - downloader - skip downloading file 000001.jpg
# 2026-05-21 15:56:51,733 - INFO - downloader - skip downloading file 000002.jpg
# 2026-05-21 15:56:51,733 - INFO - downloader - skip downloading file 000003.jpg
# 2026-05-21 15:56:51,733 - INFO - downloader - skip downloading file 000004.jpg
# 2026-05-21 15:56:51,735 - INFO - downloader - skip downloading file 000005.jpg
# 2026-05-21 15:56:51,736 - INFO - downloader - skip downloading file 000006.jpg
# 2026-05-21 15:56:51,736 - INFO - downloader - skip downloading file 000007.jpg
# 2026-05-21 15:56:51,737 - INFO - downloader - skip downloading file 000008.jpg
# 2026-05-21 15:56:51,737 - INFO - downloader - skip downloading file 000009.jpg
# 2026-05-21 15:56:51,738 - INFO - downloader - skip downloading file 000010.jpg
# 2026-05-21 15:56:51,738 - INFO - downloader - skip downloading file 000011.jpg
# 2026-05-21 15:56:51,739 - INFO - downloader - skip downloading file 000012.jpg
# 2026-05-21 15:56:51,739 - INFO - downloader - skip downloading file 000013.jpg
# 2026-05-21 15:56:51,740 - INFO - downloader - skip downloading file 000014.jpg
# 2026-05-21 15:56:51,740 - INFO - downloader - skip downloading file 000015.jpg
# 2026-05-21 15:56:51,740 - INFO - downloader - skip downloading file 000016.jpg
# 2026-05-21 15:56:51,741 - INFO - downloader - skip downloading file 000017.jpg
# 2026-05-21 15:56:52,201 - ERROR - downloader - Exception caught when downloading file https://www.dogwallpapers.net/wallpapers
- INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-05-21 15:59:16,763 - INFO - feeder - thread feeder-001 exit
# 2026-05-21 15:59:16,765 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-05-21 15:59:16,766 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-05-21 15:59:18,407 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=bird photo&pn=0&rn=30
# 2026-05-21 15:59:18,411 - INFO - downloader - skip downloading file 000001.jpg
# 2026-05-21 15:59:18,413 - INFO - downloader - skip downloading file 000002.jpg
# 2026-05-21 15:59:18,416 - INFO - downloader - skip downloading file 000003.jpg
# 2026-05-21 15:59:18,419 - INFO - downloader - skip downloading file 000004.jpg
# 2026-05-21 15:59:18,430 - INFO - downloader - skip downloading file 000005.jpg
# 2026-05-21 15:59:18,431 - INFO - downloader - skip downloading file 000006.jpg
# 2026-05-21 15:59:18,432 - INFO - downloader - skip downloading file 000007.jpg
# 2026-05-21 15:59:18,432 - INFO - downloader - skip downloading file 000008.jpg
# 2026-05-21 15:59:18,435 - INFO - downloader - skip downloading file 000009.jpg
# 2026-05-21 15:59:18,435 - INFO - downloader - skip downloading file 000010.jpg
# 2026-05-21 15:59:18,436 - INFO - downloader - skip downloading file 000011.jpg
# 2026-05-21 15:59:18,437 - INFO - downloader - skip downloading file 000012.jpg
# 2026-05-21 15:59:18,440 - INFO - downloader - skip downloading file 000013.jpg
# 2026-05-21 15:59:18,441 - INFO - downloader - skip downloading file 000014.jpg
# 2026-05-21 15:59:18,441 - INFO - downloader - skip downloading file 000015.jpg
# 2026-05-21 15:59:18,443 - INFO - downloader - skip downloading file 000016.jpg
# 2026-05-21 15:59:18,445 - INFO - downloader - skip downloading file 000017.jpg
# 2026-05-21 15:59:18,446 - INFO - downloader - skip downloading file 000018.jpg
# 2026-05-21 15:59:18,448 - INFO - downloader - skip downloading file 000019.jpg
# 2026-05-21 15:59:18,449 - INFO - downloader - skip downloading file 000020.jpg
# 2026-05-21 15:59:18,453 - INFO - downloader - skip downloading file 000021.jpg
# 2026-05-21 15:59:18,453 - INFO - downloader - skip downloading file 000022.jpg
# 2026-05-21 15:59:22,998 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=bird photo&pn=30&rn=30
# 2026-05-21 15:59:23,884 - ERROR - downloader - Exception caught when downloading file https://www.adobe.com/de/creativecloud/photography/discover/media_1e512d5b405f1789b3fc3d107be968cf0ec279453.png?width=750&format=png&optimize=medium, error: HTTPSConnectionPool(host='www.adobe.com', port=443): Read timed out. (read timeout=5), remaining retry times: 2
# 2026-05-21 15:59:29,273 - ERROR - downloader - Exception caught when downloading file https://www.adobe.com/de/creativecloud/photography/discover/media_1e512d5b405f1789b3fc3d107be968cf0ec279453.png?width=750&format=png&optimize=medium, error: HTTPSConnectionPool(host='www.adobe.com', port=443): Read timed out. (read timeout=5), remaining retry times: 1
# 
# 2026-05-21 16:00:36,640 - INFO - downloader - image #61	https://hellorfimg.zcool.cn/large/1169626465.jpg
# 2026-05-21 16:00:37,591 - INFO - downloader - image #62	https://gimg2.baidu.com/image_search/src=http%3A%2F%2Fss2.meipian.me%2Fusers%2F700773%2F848d1e73eae844888ae047ce86a9ae8b.jpg%3Fmeipian-raw%2Fbucket%2Fivwen%2Fkey%2FdXNlcnMvNzAwNzczLzg0OGQxZTczZWFlODQ0ODg4YWUwNDdjZTg2YTlhZThiLmpwZw%3D%3D%2Fsign%2Fda15fbe1da22eae75b767bb6eafedc4d.jpg&refer=http%3A%2F%2Fss2.meipian.me&app=2002&size=f9999,10000&q=a80&n=0&g=0n&fmt=auto?sec=1781938827&t=e9c5390a70c23a745bc40221b81f0d89
# 2026-05-21 16:00:37,915 - INFO - parser - no more page urls for thread parser-001 to parse
# 2026-05-21 16:00:37,916 - INFO - parser - thread parser-001 exit
# 2026-05-21 16:00:38,029 - INFO - downloader - image #63	https://img14.360buyimg.com/pop/jfs/t1/200274/31/7779/22628/613b0605Ea731cf6d/8ff323ed6053a17d.jpg
# 2026-05-21 16:00:38,489 - INFO - downloader - image #64	https://hellorfimg.zcool.cn/large/1624933654.jpg?x-image-process=image/format,webp
# 2026-05-21 16:00:38,872 - INFO - downloader - image #65	https://hellorfimg.zcool.cn/large/510065773.jpg
# 2026-05-21 16:00:39,405 - INFO - downloader - image #66	https://img.alicdn.com/bao/uploaded/i2/2221348237937/O1CN01CSVPB61zxISnchRjK_%21%214611686018427385036-0-item_pic.jpg
# 2026-05-21 16:00:44,413 - INFO - downloader - no more download task for thread downloader-001
# 2026-05-21 16:00:44,415 - INFO - downloader - thread downloader-001 exit
# 2026-05-21 16:00:44,819 - INFO - icrawler.crawler - Crawling task done!

# %% [markdown]
# ### 7. test 데이터셋 불러오기

# %%
test_dataset = ImageFolder(
    root = testset_dir,
    transform=preprocess
)
test_dataset.classes
# Out:
# ['bird', 'cat', 'dog']

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False
)

# %% [markdown]
# ### 8. test 정확도 확인

# %%
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predict = torch.max(outputs, 1)

        correct += (predict == labels).sum().item()
        total += labels.size(0)

test_acc = correct / total

print(f'테스트 정확도 : {test_acc:.4f}')
# Out:
# 테스트 정확도 : 0.7818

# %% [markdown]
# ### 9. 실제/예측값 출력

# %%
class_names = test_dataset.classes

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        prob = torch.softmax(outputs, dim =1)
        confidence, predict = torch.max(prob, 1)

        for i in range(len(labels)):
            true_label = class_names[labels[i].item()]
            pred_label = class_names[predict[i].item()]
            conf = confidence[i].item()

            print(f'실제 : {true_label} / 예측 : {pred_label} / 확률 : {conf:.4f}')
# Out:
# 실제 : bird / 예측 : bird / 확률 : 0.9991
# 실제 : bird / 예측 : bird / 확률 : 0.9519
# 실제 : bird / 예측 : bird / 확률 : 0.9924
# 실제 : bird / 예측 : bird / 확률 : 0.9905
# 실제 : bird / 예측 : bird / 확률 : 0.9944
# 실제 : bird / 예측 : bird / 확률 : 0.9835
# 실제 : bird / 예측 : bird / 확률 : 0.9946
# 실제 : bird / 예측 : bird / 확률 : 0.9950
# 실제 : bird / 예측 : bird / 확률 : 0.9972
# 실제 : bird / 예측 : bird / 확률 : 0.9962
# 실제 : bird / 예측 : bird / 확률 : 0.9781
# 실제 : bird / 예측 : bird / 확률 : 0.9944
# 실제 : bird / 예측 : bird / 확률 : 0.9695
# 실제 : bird / 예측 : bird / 확률 : 0.9928
# 실제 : bird / 예측 : bird / 확률 : 0.9902
# 실제 : bird / 예측 : bird / 확률 : 0.9719
# 실제 : bird / 예측 : bird / 확률 : 0.9891
# 실제 : bird / 예측 : bird / 확률 : 0.9899
# 실제 : bird / 예측 : bird / 확률 : 0.9389
# 실제 : bird / 예측 : bird / 확률 : 0.9977
# 실제 : bird / 예측 : bird / 확률 : 0.9837
# 실제 : bird / 예측 : bird / 확률 : 0.9842
# 실제 : bird / 예측 : bird / 확률 : 0.9271
# 실제 : bird / 예측 : bird / 확률 : 0.9978
# 실제 : bird / 예측 : bird / 확률 : 0.8882
# 실제 : bird / 예측 : bird / 확률 : 0.9571
# 실제 : bird / 예측 : bird / 확률 : 0.9944
# 실제 : bird / 예측 : bird / 확률 : 0.9970
# 실제 : bird / 예측 : bird / 확률 : 0.9975
# 실제 : bird / 예측 : bird / 확률 : 0.9804
# 실제 : bird / 예측 : bird / 확률 : 0.8684
# 실제 : bird / 예측 : bird / 확률 : 0.9897
# 실제 : bird / 예측 : bird / 확률 : 0.9664
# 실제 : bird / 예측 : bird / 확률 : 0.9724
# 실제 : bird / 예측 : bird / 확률 : 0.9236
# 실제 : bird / 예측 : bird / 확률 : 0.9486
# 실제 : bird / 예측 : bird / 확률 : 0.9951
# 실제 : bird / 예측 : bird / 확률 : 0.9987
# 실제 : bird / 예측 : bird / 확률 : 0.9076
# 실제 : bird / 예측 : bird / 확률 : 0.9930
# 실제 : bird / 예측 : bird / 확률 : 0.9695
# 실제 : bird / 예측 : bird / 확률 : 0.9123
# 실제 : bird / 예측 : bird / 확률 : 0.9202
# 실제 : bird / 예측 : bird / 확률 : 0.5227
# 실제 : bird / 예측 : bird / 확률 : 0.9029
# 실제 : bird / 예측 : bird / 확률 : 0.9603
# 실제 : bird / 예측 : bird / 확률 : 0.9747
# 실제 : bird / 예측 : bird / 확률 : 0.9984
# 실제 : bird / 예측 : bird / 확률 : 0.9261
# 실제 : bird / 예측 : bird / 확률 : 0.7954
# 실제 : bird / 예측 : bird / 확률 : 0.9553
# 실제 : bird / 예측 : bird / 확률 : 0.9860
# 실제 : bird / 예측 : bird / 확률 : 0.9989
# 실제 : bird / 예측 : bird / 확률 : 0.9930
# 실제 : bird / 예측 : bird / 확률 : 0.9940
# 실제 : bird / 예측 : bird / 확률 : 0.8700
# 실제 : bird / 예측 : bird / 확률 : 0.8885
# 실제 : bird / 예측 : bird / 확률 : 0.9993
# 실제 : bird / 예측 : bird / 확률 : 0.9903
# 실제 : bird / 예측 : bird / 확률 : 0.9592
# 실제 : bird / 예측 : bird / 확률 : 0.9980
# 실제 : bird / 예측 : bird / 확률 : 0.9771
# 실제 : bird / 예측 : bird / 확률 : 0.3650
# 실제 : bird / 예측 : bird / 확률 : 0.9851
# 실제 : bird / 예측 : bird / 확률 : 0.8704
# 실제 : bird / 예측 : bird / 확률 : 0.9296
# 실제 : bird / 예측 : bird / 확률 : 0.8303
# 실제 : cat / 예측 : cat / 확률 : 0.9948
# 실제 : cat / 예측 : cat / 확률 : 0.9899
# 실제 : cat / 예측 : cat / 확률 : 0.9832
# 실제 : cat / 예측 : cat / 확률 : 0.9896
# 실제 : cat / 예측 : cat / 확률 : 0.9697
# 실제 : cat / 예측 : cat / 확률 : 0.9954
# 실제 : cat / 예측 : cat / 확률 : 0.9902
# 실제 : cat / 예측 : cat / 확률 : 0.9780
# 실제 : cat / 예측 : cat / 확률 : 0.8918
# 실제 : cat / 예측 : cat / 확률 : 0.9981
# 실제 : cat / 예측 : cat / 확률 : 0.9666
# 실제 : cat / 예측 : cat / 확률 : 0.9840
# 실제 : cat / 예측 : cat / 확률 : 0.9741
# 실제 : cat / 예측 : cat / 확률 : 0.9780
# 실제 : cat / 예측 : cat / 확률 : 0.9252
# 실제 : cat / 예측 : cat / 확률 : 0.9941
# 실제 : cat / 예측 : cat / 확률 : 0.9932
# 실제 : cat / 예측 : cat / 확률 : 0.9878
# 실제 : cat / 예측 : cat / 확률 : 0.9774
# 실제 : cat / 예측 : bird / 확률 : 0.5150
# 실제 : cat / 예측 : cat / 확률 : 0.9573
# 실제 : cat / 예측 : cat / 확률 : 0.9782
# 실제 : cat / 예측 : cat / 확률 : 0.9958
# 실제 : cat / 예측 : dog / 확률 : 0.7564
# 실제 : cat / 예측 : cat / 확률 : 0.9771
# 실제 : cat / 예측 : cat / 확률 : 0.9319
# 실제 : cat / 예측 : cat / 확률 : 0.9948
# 실제 : cat / 예측 : cat / 확률 : 0.9902
# 실제 : cat / 예측 : cat / 확률 : 0.9393
# 실제 : cat / 예측 : cat / 확률 : 0.9502
# 실제 : cat / 예측 : cat / 확률 : 0.9515
# 실제 : cat / 예측 : cat / 확률 : 0.8054
# 실제 : cat / 예측 : cat / 확률 : 0.8619
# 실제 : cat / 예측 : cat / 확률 : 0.9646
# 실제 : cat / 예측 : cat / 확률 : 0.5884
# 실제 : cat / 예측 : cat / 확률 : 0.6438
# 실제 : cat / 예측 : cat / 확률 : 0.8406
# 실제 : cat / 예측 : cat / 확률 : 0.9172
# 실제 : cat / 예측 : cat / 확률 : 0.9879
# 실제 : cat / 예측 : cat / 확률 : 0.8119
# 실제 : cat / 예측 : cat / 확률 : 0.9559
# 실제 : cat / 예측 : cat / 확률 : 0.9756
# 실제 : cat / 예측 : cat / 확률 : 0.9613
# 실제 : cat / 예측 : cat / 확률 : 0.9232
# 실제 : cat / 예측 : cat / 확률 : 0.9723
# 실제 : cat / 예측 : cat / 확률 : 0.5559
# 실제 : cat / 예측 : cat / 확률 : 0.8317
# 실제 : cat / 예측 : cat / 확률 : 0.9776
# 실제 : cat / 예측 : cat / 확률 : 0.9482
# 실제 : cat / 예측 : cat / 확률 : 0.8102
# 실제 : cat / 예측 : cat / 확률 : 0.9093
# 실제 : cat / 예측 : cat / 확률 : 0.9301
# 실제 : cat / 예측 : cat / 확률 : 0.9652
# 실제 : cat / 예측 : cat / 확률 : 0.9943
# 실제 : cat / 예측 : cat / 확률 : 0.9031
# 실제 : cat / 예측 : cat / 확률 : 0.9861
# 실제 : cat / 예측 : cat / 확률 : 0.9383
# 실제 : cat / 예측 : cat / 확률 : 0.9030
# 실제 : cat / 예측 : cat / 확률 : 0.9077
# 실제 : cat / 예측 : bird / 확률 : 0.3650
# 실제 : cat / 예측 : cat / 확률 : 0.5840
# 실제 : cat / 예측 : cat / 확률 : 0.8899
# 실제 : cat / 예측 : cat / 확률 : 0.9798
# 실제 : cat / 예측 : cat / 확률 : 0.6389
# 실제 : cat / 예측 : cat / 확률 : 0.9870
# 실제 : cat / 예측 : cat / 확률 : 0.9807
# 실제 : cat / 예측 : cat / 확률 : 0.7195
# 실제 : cat / 예측 : cat / 확률 : 0.9202
# 실제 : cat / 예측 : cat / 확률 : 0.9038
# 실제 : cat / 예측 : cat / 확률 : 0.9763
# 실제 : cat / 예측 : cat / 확률 : 0.9738
# 실제 : cat / 예측 : cat / 확률 : 0.9337
# 실제 : cat / 예측 : cat / 확률 : 0.4799
# 실제 : cat / 예측 : cat / 확률 : 0.5307
# 실제 : cat / 예측 : cat / 확률 : 0.9344
# 실제 : cat / 예측 : cat / 확률 : 0.9810
# 실제 : cat / 예측 : cat / 확률 : 0.9956
# 실제 : cat / 예측 : dog / 확률 : 0.8015
# 실제 : cat / 예측 : cat / 확률 : 0.8850
# 실제 : cat / 예측 : cat / 확률 : 0.9074
# 실제 : cat / 예측 : bird / 확률 : 0.4615
# 실제 : cat / 예측 : cat / 확률 : 0.9983
# 실제 : cat / 예측 : cat / 확률 : 0.8169
# 실제 : cat / 예측 : cat / 확률 : 0.9597
# 실제 : cat / 예측 : cat / 확률 : 0.4564
# 실제 : cat / 예측 : cat / 확률 : 0.6971
# 실제 : cat / 예측 : cat / 확률 : 0.7593
# 실제 : cat / 예측 : cat / 확률 : 0.8594
# 실제 : cat / 예측 : cat / 확률 : 0.6235
# 실제 : cat / 예측 : cat / 확률 : 0.9977
# 실제 : dog / 예측 : dog / 확률 : 0.9846
# 실제 : dog / 예측 : dog / 확률 : 0.9982
# 실제 : dog / 예측 : dog / 확률 : 0.9898
# 실제 : dog / 예측 : dog / 확률 : 0.9927
# 실제 : dog / 예측 : dog / 확률 : 0.9881
# 실제 : dog / 예측 : dog / 확률 : 0.9677
# 실제 : dog / 예측 : dog / 확률 : 0.9870
# 실제 : dog / 예측 : dog / 확률 : 0.9745
# 실제 : dog / 예측 : dog / 확률 : 0.9624
# 실제 : dog / 예측 : dog / 확률 : 0.9837
# 실제 : dog / 예측 : dog / 확률 : 0.9883
# 실제 : dog / 예측 : dog / 확률 : 0.9422
# 실제 : dog / 예측 : dog / 확률 : 0.9772
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9911
# 실제 : dog / 예측 : dog / 확률 : 0.9701
# 실제 : dog / 예측 : dog / 확률 : 0.9410
# 실제 : dog / 예측 : dog / 확률 : 0.9951
# 실제 : dog / 예측 : dog / 확률 : 0.9885
# 실제 : dog / 예측 : dog / 확률 : 0.9783
# 실제 : dog / 예측 : dog / 확률 : 0.9792
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9931
# 실제 : dog / 예측 : dog / 확률 : 0.8275
# 실제 : dog / 예측 : dog / 확률 : 0.9490
# 실제 : dog / 예측 : dog / 확률 : 0.8695
# 실제 : dog / 예측 : dog / 확률 : 0.9958
# 실제 : dog / 예측 : dog / 확률 : 0.8979
# 실제 : dog / 예측 : dog / 확률 : 0.7564
# 실제 : dog / 예측 : dog / 확률 : 0.8037
# 실제 : dog / 예측 : dog / 확률 : 0.7733
# 실제 : dog / 예측 : dog / 확률 : 0.9394
# 실제 : dog / 예측 : dog / 확률 : 0.7791
# 실제 : dog / 예측 : cat / 확률 : 0.7745
# 실제 : dog / 예측 : dog / 확률 : 0.6900
# 실제 : dog / 예측 : dog / 확률 : 0.9112
# 실제 : dog / 예측 : dog / 확률 : 0.9890
# 실제 : dog / 예측 : dog / 확률 : 0.6217
# 실제 : dog / 예측 : dog / 확률 : 0.6634
# 실제 : dog / 예측 : dog / 확률 : 0.8926
# 실제 : dog / 예측 : dog / 확률 : 0.9598
# 실제 : dog / 예측 : dog / 확률 : 0.9687
# 실제 : dog / 예측 : dog / 확률 : 0.9745
# 실제 : dog / 예측 : dog / 확률 : 0.9515
# 실제 : dog / 예측 : dog / 확률 : 0.6676
# 실제 : dog / 예측 : dog / 확률 : 0.9584
# 실제 : dog / 예측 : dog / 확률 : 0.7097
# 실제 : dog / 예측 : dog / 확률 : 0.8911
# 실제 : dog / 예측 : dog / 확률 : 0.7694
# 실제 : dog / 예측 : dog / 확률 : 0.7949
# 실제 : dog / 예측 : dog / 확률 : 0.9045
# 실제 : dog / 예측 : dog / 확률 : 0.6069
# 실제 : dog / 예측 : dog / 확률 : 0.8107
# 실제 : dog / 예측 : dog / 확률 : 0.6262
# 실제 : dog / 예측 : dog / 확률 : 0.9164
# 실제 : dog / 예측 : dog / 확률 : 0.9483
# 실제 : dog / 예측 : dog / 확률 : 0.9241
# 실제 : dog / 예측 : dog / 확률 : 0.9234
# 실제 : dog / 예측 : dog / 확률 : 0.8215
# 실제 : dog / 예측 : dog / 확률 : 0.6281
# 실제 : dog / 예측 : dog / 확률 : 0.8652
# 실제 : dog / 예측 : dog / 확률 : 0.9795
# 실제 : dog / 예측 : dog / 확률 : 0.6247
# 실제 : dog / 예측 : dog / 확률 : 0.8885
# 실제 : dog / 예측 : cat / 확률 : 0.8979
# 실제 : dog / 예측 : dog / 확률 : 0.7859
# 실제 : dog / 예측 : dog / 확률 : 0.9981
# 실제 : dog / 예측 : dog / 확률 : 0.9388
# 실제 : dog / 예측 : dog / 확률 : 0.8800
# 실제 : dog / 예측 : dog / 확률 : 0.9250
# 실제 : dog / 예측 : dog / 확률 : 0.8390
# 실제 : dog / 예측 : dog / 확률 : 0.9974
# 실제 : dog / 예측 : dog / 확률 : 0.9846
# 실제 : dog / 예측 : dog / 확률 : 0.9936
# 실제 : dog / 예측 : dog / 확률 : 0.9898
# 실제 : dog / 예측 : dog / 확률 : 0.9916
# 실제 : dog / 예측 : dog / 확률 : 0.9982
# 실제 : dog / 예측 : dog / 확률 : 0.9893
# 실제 : dog / 예측 : dog / 확률 : 0.9927
# 실제 : dog / 예측 : dog / 확률 : 0.9862
# 실제 : dog / 예측 : bird / 확률 : 0.6636
# 실제 : dog / 예측 : bird / 확률 : 0.5431
# 실제 : dog / 예측 : bird / 확률 : 0.4925
# 실제 : dog / 예측 : dog / 확률 : 0.4984
# 실제 : dog / 예측 : dog / 확률 : 0.6745
# 실제 : dog / 예측 : bird / 확률 : 0.5946
# 실제 : dog / 예측 : bird / 확률 : 0.4803
# 실제 : dog / 예측 : bird / 확률 : 0.6921
# 실제 : dog / 예측 : bird / 확률 : 0.7739
# 실제 : dog / 예측 : dog / 확률 : 0.5941
# 실제 : dog / 예측 : bird / 확률 : 0.7234
# 실제 : dog / 예측 : dog / 확률 : 0.5158
# 실제 : dog / 예측 : bird / 확률 : 0.5967
# 실제 : dog / 예측 : bird / 확률 : 0.4417
# 실제 : dog / 예측 : dog / 확률 : 0.7788
# 실제 : dog / 예측 : dog / 확률 : 0.7735
# 실제 : dog / 예측 : dog / 확률 : 0.5255
# 실제 : dog / 예측 : dog / 확률 : 0.5754
# 실제 : dog / 예측 : bird / 확률 : 0.7271
# 실제 : dog / 예측 : dog / 확률 : 0.8146
# 실제 : dog / 예측 : bird / 확률 : 0.5440
# 실제 : dog / 예측 : dog / 확률 : 0.6568
# 실제 : dog / 예측 : bird / 확률 : 0.4153
# 실제 : dog / 예측 : dog / 확률 : 0.3759
# 실제 : dog / 예측 : bird / 확률 : 0.5088
# 실제 : dog / 예측 : dog / 확률 : 0.7311
# 실제 : dog / 예측 : bird / 확률 : 0.5277
# 실제 : dog / 예측 : bird / 확률 : 0.7773
# 실제 : dog / 예측 : dog / 확률 : 0.9846
# 실제 : dog / 예측 : dog / 확률 : 0.9982
# 실제 : dog / 예측 : dog / 확률 : 0.9898
# 실제 : dog / 예측 : dog / 확률 : 0.9927
# 실제 : dog / 예측 : dog / 확률 : 0.9881
# 실제 : dog / 예측 : dog / 확률 : 0.9677
# 실제 : dog / 예측 : dog / 확률 : 0.9870
# 실제 : dog / 예측 : dog / 확률 : 0.9745
# 실제 : dog / 예측 : dog / 확률 : 0.9624
# 실제 : dog / 예측 : dog / 확률 : 0.9837
# 실제 : dog / 예측 : dog / 확률 : 0.9883
# 실제 : dog / 예측 : dog / 확률 : 0.9422
# 실제 : dog / 예측 : dog / 확률 : 0.9772
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9911
# 실제 : dog / 예측 : dog / 확률 : 0.9701
# 실제 : dog / 예측 : dog / 확률 : 0.9410
# 실제 : dog / 예측 : dog / 확률 : 0.9951
# 실제 : dog / 예측 : dog / 확률 : 0.9885
# 실제 : dog / 예측 : dog / 확률 : 0.9783
# 실제 : dog / 예측 : dog / 확률 : 0.9792
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9931
# 실제 : dog / 예측 : dog / 확률 : 0.9846
# 실제 : dog / 예측 : dog / 확률 : 0.9982
# 실제 : dog / 예측 : dog / 확률 : 0.9898
# 실제 : dog / 예측 : dog / 확률 : 0.9927
# 실제 : dog / 예측 : dog / 확률 : 0.9881
# 실제 : dog / 예측 : dog / 확률 : 0.9677
# 실제 : dog / 예측 : dog / 확률 : 0.9870
# 실제 : dog / 예측 : dog / 확률 : 0.9745
# 실제 : dog / 예측 : dog / 확률 : 0.9624
# 실제 : dog / 예측 : dog / 확률 : 0.9837
# 실제 : dog / 예측 : dog / 확률 : 0.9883
# 실제 : dog / 예측 : dog / 확률 : 0.9422
# 실제 : dog / 예측 : dog / 확률 : 0.9772
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9911
# 실제 : dog / 예측 : dog / 확률 : 0.9701
# 실제 : dog / 예측 : dog / 확률 : 0.9410
# 실제 : dog / 예측 : dog / 확률 : 0.9951
# 실제 : dog / 예측 : dog / 확률 : 0.9885
# 실제 : dog / 예측 : dog / 확률 : 0.9783
# 실제 : dog / 예측 : dog / 확률 : 0.9792
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9931
# 실제 : dog / 예측 : dog / 확률 : 0.9846
# 실제 : dog / 예측 : dog / 확률 : 0.9982
# 실제 : dog / 예측 : dog / 확률 : 0.9898
# 실제 : dog / 예측 : dog / 확률 : 0.9927
# 실제 : dog / 예측 : dog / 확률 : 0.9881
# 실제 : dog / 예측 : dog / 확률 : 0.9677
# 실제 : dog / 예측 : dog / 확률 : 0.9870
# 실제 : dog / 예측 : dog / 확률 : 0.9745
# 실제 : dog / 예측 : dog / 확률 : 0.9624
# 실제 : dog / 예측 : dog / 확률 : 0.9837
# 실제 : dog / 예측 : dog / 확률 : 0.9883
# 실제 : dog / 예측 : dog / 확률 : 0.9422
# 실제 : dog / 예측 : dog / 확률 : 0.9772
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9911
# 실제 : dog / 예측 : dog / 확률 : 0.9701
# 실제 : dog / 예측 : dog / 확률 : 0.9410
# 실제 : dog / 예측 : dog / 확률 : 0.9951
# 실제 : dog / 예측 : dog / 확률 : 0.9885
# 실제 : dog / 예측 : dog / 확률 : 0.9783
# 실제 : dog / 예측 : dog / 확률 : 0.9792
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9931
# 실제 : dog / 예측 : dog / 확률 : 0.9846
# 실제 : dog / 예측 : dog / 확률 : 0.9982
# 실제 : dog / 예측 : dog / 확률 : 0.9898
# 실제 : dog / 예측 : dog / 확률 : 0.9927
# 실제 : dog / 예측 : dog / 확률 : 0.9881
# 실제 : dog / 예측 : dog / 확률 : 0.9677
# 실제 : dog / 예측 : dog / 확률 : 0.9870
# 실제 : dog / 예측 : dog / 확률 : 0.9745
# 실제 : dog / 예측 : dog / 확률 : 0.9624
# 실제 : dog / 예측 : dog / 확률 : 0.9837
# 실제 : dog / 예측 : dog / 확률 : 0.9883
# 실제 : dog / 예측 : dog / 확률 : 0.9422
# 실제 : dog / 예측 : dog / 확률 : 0.9772
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9911
# 실제 : dog / 예측 : dog / 확률 : 0.9701
# 실제 : dog / 예측 : dog / 확률 : 0.9410
# 실제 : dog / 예측 : dog / 확률 : 0.9951
# 실제 : dog / 예측 : dog / 확률 : 0.9885
# 실제 : dog / 예측 : dog / 확률 : 0.9783
# 실제 : dog / 예측 : dog / 확률 : 0.9792
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9931
# 실제 : dog / 예측 : bird / 확률 : 0.8521
# 실제 : dog / 예측 : bird / 확률 : 0.3890
# 실제 : dog / 예측 : bird / 확률 : 0.5903
# 실제 : dog / 예측 : bird / 확률 : 0.7583
# 실제 : dog / 예측 : dog / 확률 : 0.4745
# 실제 : dog / 예측 : bird / 확률 : 0.7058
# 실제 : dog / 예측 : bird / 확률 : 0.8469
# 실제 : dog / 예측 : bird / 확률 : 0.5084
# 실제 : dog / 예측 : bird / 확률 : 0.9561
# 실제 : dog / 예측 : bird / 확률 : 0.4070
# 실제 : dog / 예측 : bird / 확률 : 0.6568
# 실제 : dog / 예측 : bird / 확률 : 0.6986
# 실제 : dog / 예측 : bird / 확률 : 0.7175
# 실제 : dog / 예측 : bird / 확률 : 0.4935
# 실제 : dog / 예측 : bird / 확률 : 0.8856
# 실제 : dog / 예측 : bird / 확률 : 0.8278
# 실제 : dog / 예측 : bird / 확률 : 0.6405
# 실제 : dog / 예측 : bird / 확률 : 0.4788
# 실제 : dog / 예측 : dog / 확률 : 0.4644
# 실제 : dog / 예측 : cat / 확률 : 0.3654
# 실제 : dog / 예측 : bird / 확률 : 0.8171
# 실제 : dog / 예측 : bird / 확률 : 0.7890
# 실제 : dog / 예측 : dog / 확률 : 0.4652
# 실제 : dog / 예측 : bird / 확률 : 0.6529
# 실제 : dog / 예측 : dog / 확률 : 0.5843
# 실제 : dog / 예측 : dog / 확률 : 0.9358
# 실제 : dog / 예측 : dog / 확률 : 0.3628
# 실제 : dog / 예측 : bird / 확률 : 0.8167
# 실제 : dog / 예측 : bird / 확률 : 0.4966
# 실제 : dog / 예측 : dog / 확률 : 0.4593
# 실제 : dog / 예측 : bird / 확률 : 0.4954
# 실제 : dog / 예측 : bird / 확률 : 0.6976
# 실제 : dog / 예측 : bird / 확률 : 0.7286
# 실제 : dog / 예측 : bird / 확률 : 0.5536
# 실제 : dog / 예측 : bird / 확률 : 0.4687
# 실제 : dog / 예측 : dog / 확률 : 0.4364
# 실제 : dog / 예측 : bird / 확률 : 0.5565
# 실제 : dog / 예측 : bird / 확률 : 0.6865
# 실제 : dog / 예측 : cat / 확률 : 0.9584
# 실제 : dog / 예측 : bird / 확률 : 0.5293
# 실제 : dog / 예측 : bird / 확률 : 0.8649
# 실제 : dog / 예측 : bird / 확률 : 0.6862
# 실제 : dog / 예측 : bird / 확률 : 0.4113
# 실제 : dog / 예측 : dog / 확률 : 0.9838
# 실제 : dog / 예측 : bird / 확률 : 0.7258
# 실제 : dog / 예측 : bird / 확률 : 0.7562
# 실제 : dog / 예측 : bird / 확률 : 0.6135
# 실제 : dog / 예측 : bird / 확률 : 0.3985
# 실제 : dog / 예측 : bird / 확률 : 0.5529
# 실제 : dog / 예측 : bird / 확률 : 0.7839
# 실제 : dog / 예측 : bird / 확률 : 0.7081
# 실제 : dog / 예측 : bird / 확률 : 0.4427
# 실제 : dog / 예측 : bird / 확률 : 0.6223
# 실제 : dog / 예측 : bird / 확률 : 0.7192
# 실제 : dog / 예측 : dog / 확률 : 0.4998
# 실제 : dog / 예측 : bird / 확률 : 0.6383
# 실제 : dog / 예측 : bird / 확률 : 0.3880
# 실제 : dog / 예측 : bird / 확률 : 0.5713
# 실제 : dog / 예측 : bird / 확률 : 0.5579
# 실제 : dog / 예측 : bird / 확률 : 0.5768
# 실제 : dog / 예측 : bird / 확률 : 0.7386
# 실제 : dog / 예측 : bird / 확률 : 0.5805
# 실제 : dog / 예측 : bird / 확률 : 0.4268
# 실제 : dog / 예측 : cat / 확률 : 0.3592
# 실제 : dog / 예측 : bird / 확률 : 0.7015
# 실제 : dog / 예측 : dog / 확률 : 0.9846
# 실제 : dog / 예측 : dog / 확률 : 0.9982
# 실제 : dog / 예측 : dog / 확률 : 0.9898
# 실제 : dog / 예측 : dog / 확률 : 0.9927
# 실제 : dog / 예측 : dog / 확률 : 0.9881
# 실제 : dog / 예측 : dog / 확률 : 0.9677
# 실제 : dog / 예측 : dog / 확률 : 0.9870
# 실제 : dog / 예측 : dog / 확률 : 0.9745
# 실제 : dog / 예측 : dog / 확률 : 0.9624
# 실제 : dog / 예측 : dog / 확률 : 0.9837
# 실제 : dog / 예측 : dog / 확률 : 0.9883
# 실제 : dog / 예측 : dog / 확률 : 0.9422
# 실제 : dog / 예측 : dog / 확률 : 0.9772
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9911
# 실제 : dog / 예측 : dog / 확률 : 0.9701
# 실제 : dog / 예측 : dog / 확률 : 0.9951
# 실제 : dog / 예측 : dog / 확률 : 0.9885
# 실제 : dog / 예측 : dog / 확률 : 0.9783
# 실제 : dog / 예측 : dog / 확률 : 0.9792
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9931
# 실제 : dog / 예측 : dog / 확률 : 0.4914
# 실제 : dog / 예측 : bird / 확률 : 0.5195
# 실제 : dog / 예측 : bird / 확률 : 0.6817
# 실제 : dog / 예측 : dog / 확률 : 0.7287
# 실제 : dog / 예측 : bird / 확률 : 0.6004
# 실제 : dog / 예측 : bird / 확률 : 0.5981
# 실제 : dog / 예측 : dog / 확률 : 0.9846
# 실제 : dog / 예측 : dog / 확률 : 0.9982
# 실제 : dog / 예측 : dog / 확률 : 0.9898
# 실제 : dog / 예측 : dog / 확률 : 0.9927
# 실제 : dog / 예측 : dog / 확률 : 0.9881
# 실제 : dog / 예측 : dog / 확률 : 0.9677
# 실제 : dog / 예측 : dog / 확률 : 0.9870
# 실제 : dog / 예측 : dog / 확률 : 0.9745
# 실제 : dog / 예측 : dog / 확률 : 0.9624
# 실제 : dog / 예측 : dog / 확률 : 0.9837
# 실제 : dog / 예측 : dog / 확률 : 0.9883
# 실제 : dog / 예측 : dog / 확률 : 0.9422
# 실제 : dog / 예측 : dog / 확률 : 0.9772
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9911
# 실제 : dog / 예측 : dog / 확률 : 0.9701
# 실제 : dog / 예측 : dog / 확률 : 0.9885
# 실제 : dog / 예측 : dog / 확률 : 0.9783
# 실제 : dog / 예측 : dog / 확률 : 0.9792
# 실제 : dog / 예측 : dog / 확률 : 0.9866
# 실제 : dog / 예측 : dog / 확률 : 0.9931
# 실제 : dog / 예측 : bird / 확률 : 0.6282
# 실제 : dog / 예측 : bird / 확률 : 0.6757
# 실제 : dog / 예측 : dog / 확률 : 0.9822
# 실제 : dog / 예측 : dog / 확률 : 0.9431
# 실제 : dog / 예측 : dog / 확률 : 0.8714
# 실제 : dog / 예측 : dog / 확률 : 0.9849
# 실제 : dog / 예측 : dog / 확률 : 0.9530
# 실제 : dog / 예측 : dog / 확률 : 0.9241
# 실제 : dog / 예측 : dog / 확률 : 0.8608
# 실제 : dog / 예측 : dog / 확률 : 0.9359
# 실제 : dog / 예측 : dog / 확률 : 0.8619
# 실제 : dog / 예측 : dog / 확률 : 0.8442
# 실제 : dog / 예측 : dog / 확률 : 0.5070
# 실제 : dog / 예측 : dog / 확률 : 0.5554
# 실제 : dog / 예측 : dog / 확률 : 0.9613
# 실제 : dog / 예측 : dog / 확률 : 0.8762
# 실제 : dog / 예측 : dog / 확률 : 0.7733
# 실제 : dog / 예측 : dog / 확률 : 0.4304
# 실제 : dog / 예측 : dog / 확률 : 0.6284
# 실제 : dog / 예측 : bird / 확률 : 0.5431
# 실제 : dog / 예측 : cat / 확률 : 0.6452
# 실제 : dog / 예측 : dog / 확률 : 0.9164
# 실제 : dog / 예측 : dog / 확률 : 0.9554
# 실제 : dog / 예측 : dog / 확률 : 0.5665
# 실제 : dog / 예측 : dog / 확률 : 0.9155
# 실제 : dog / 예측 : dog / 확률 : 0.9815
# 실제 : dog / 예측 : dog / 확률 : 0.9227
# 실제 : dog / 예측 : dog / 확률 : 0.7529
# 실제 : dog / 예측 : dog / 확률 : 0.9039
# 실제 : dog / 예측 : dog / 확률 : 0.7182
# 실제 : dog / 예측 : dog / 확률 : 0.5996
# 실제 : dog / 예측 : dog / 확률 : 0.9680
# 실제 : dog / 예측 : dog / 확률 : 0.5316
# 실제 : dog / 예측 : dog / 확률 : 0.7508
# 실제 : dog / 예측 : dog / 확률 : 0.8126
# 실제 : dog / 예측 : cat / 확률 : 0.6322
# 실제 : dog / 예측 : dog / 확률 : 0.9658
# 실제 : dog / 예측 : dog / 확률 : 0.8134
# 실제 : dog / 예측 : cat / 확률 : 0.6636
# 실제 : dog / 예측 : bird / 확률 : 0.5105
# 실제 : dog / 예측 : dog / 확률 : 0.6308
# 실제 : dog / 예측 : dog / 확률 : 0.7477
# 실제 : dog / 예측 : bird / 확률 : 0.7153
# 실제 : dog / 예측 : dog / 확률 : 0.6425
# 실제 : dog / 예측 : bird / 확률 : 0.7153
# 실제 : dog / 예측 : dog / 확률 : 0.4690
# 실제 : dog / 예측 : bird / 확률 : 0.6224
# 실제 : dog / 예측 : bird / 확률 : 0.8006
# 실제 : dog / 예측 : bird / 확률 : 0.5268
# 실제 : dog / 예측 : bird / 확률 : 0.7109
# 실제 : dog / 예측 : bird / 확률 : 0.6293
# 실제 : dog / 예측 : bird / 확률 : 0.5016
# 실제 : dog / 예측 : dog / 확률 : 0.4319
# 실제 : dog / 예측 : dog / 확률 : 0.4723
# 실제 : dog / 예측 : dog / 확률 : 0.5840
# 실제 : dog / 예측 : dog / 확률 : 0.5833
# 실제 : dog / 예측 : dog / 확률 : 0.4563
# 실제 : dog / 예측 : bird / 확률 : 0.5421
# 실제 : dog / 예측 : dog / 확률 : 0.4844
# 실제 : dog / 예측 : dog / 확률 : 0.3608
# 실제 : dog / 예측 : bird / 확률 : 0.6307
# 실제 : dog / 예측 : bird / 확률 : 0.4067
# 실제 : dog / 예측 : dog / 확률 : 0.5585
# 실제 : dog / 예측 : bird / 확률 : 0.6772
# 실제 : dog / 예측 : bird / 확률 : 0.6193
# 실제 : dog / 예측 : dog / 확률 : 0.6408
# 실제 : dog / 예측 : dog / 확률 : 0.4510
# 실제 : dog / 예측 : dog / 확률 : 0.5073
# 실제 : dog / 예측 : bird / 확률 : 0.5090
# 실제 : dog / 예측 : bird / 확률 : 0.5703
# 실제 : dog / 예측 : bird / 확률 : 0.5418
# 실제 : dog / 예측 : bird / 확률 : 0.8097
# 실제 : dog / 예측 : bird / 확률 : 0.6128
# 실제 : dog / 예측 : cat / 확률 : 0.7474
# 실제 : dog / 예측 : cat / 확률 : 0.4833
# 실제 : dog / 예측 : bird / 확률 : 0.5043
# 실제 : dog / 예측 : bird / 확률 : 0.6599
# 실제 : dog / 예측 : cat / 확률 : 0.4583
# 실제 : dog / 예측 : bird / 확률 : 0.4581
# 실제 : dog / 예측 : bird / 확률 : 0.8191
# 실제 : dog / 예측 : bird / 확률 : 0.5984
# 실제 : dog / 예측 : cat / 확률 : 0.3887
# 실제 : dog / 예측 : bird / 확률 : 0.5930
# 실제 : dog / 예측 : bird / 확률 : 0.3870
# 실제 : dog / 예측 : bird / 확률 : 0.6666
# 실제 : dog / 예측 : bird / 확률 : 0.5013
# 실제 : dog / 예측 : bird / 확률 : 0.4366
# 실제 : dog / 예측 : cat / 확률 : 0.5358

# %% [markdown]
# ### 10. 시각화

# %%
batch_size = 8
all_batches = list(test_loader)

images, labels = all_batches[0]

model.eval()

with torch.no_grad():
    outputs = model(images.to(device))

    prob = torch.softmax(outputs, dim = 1)
    confidence, predict = torch.max(prob,1)

plt.figure(figsize=(12,6))

for i in range(min(8,len(images))):
    image = images[i].permute(1,2,0).numpy()

    true_label = class_names[labels[i].item()]
    pred_label = class_names[predict[i].item()]

    conf = confidence[i].item()

    # 2행 4열 형태로 이미지 출력
    plt.subplot(2,4,i+1)
    plt.imshow(image)

    plt.title(f'True : {true_label} / Pred : {pred_label} / Acc : {conf:.2f}')
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 2026-05-21 16:56:04,236 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.622571].
# 2026-05-21 16:56:04,242 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.6051416].
# 2026-05-21 16:56:04,248 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.4110641].
# 2026-05-21 16:56:04,255 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.5005665].
# 2026-05-21 16:56:04,262 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0494049..2.3410363].
# 2026-05-21 16:56:04,270 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0836544..2.64].
# 2026-05-21 16:56:04,277 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.5528543].
# 2026-05-21 16:56:04,284 - WARNING - matplotlib.image - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1007793..2.4308496].
