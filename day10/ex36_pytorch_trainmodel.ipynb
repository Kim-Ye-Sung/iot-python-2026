# %% [markdown]
# ## 저장한 모델 사용하기

# %% [markdown]
# ### 1. 라이브러리 로드

# %%
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim

import requests
from PIL import Image
from io import BytesIO
import os
import random
import shutil

# 사전학습 모델 라이브러리 추가
from torchvision.models import resnet18, ResNet18_Weights
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder

# pip install icrawler
from icrawler.builtin import BingImageCrawler, BaiduImageCrawler

import matplotlib.pyplot as plt

# %%
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.version.cuda)
print(torch.cuda.get_device_name(0))
# Out:
# 2.12.0+cu130
# True
# 13.0
# NVIDIA GeForce RTX 5060

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### 2. 설정

# %%
model_path = 'resnet18_bird_cat_dog.pth'
test_dir = 'dataset/test'

num_classes = 3
batch_size = 16

# %% [markdown]
# ### 3. ResNet18 모델구조 재생성

# %%
weight = ResNet18_Weights.DEFAULT
model = resnet18(weights=weight)

model.fc = nn.Linear(
    in_features=model.fc.in_features,
    out_features=num_classes
)

model = model.to(device=device)

# %% [markdown]
# ### 4. pth 모델파일 로드

# %%
model.load_state_dict(
    torch.load(model_path, map_location=device)
)

model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=3, bias=True)
# )

# %% [markdown]
# ### 5. 전처리 설정

# %%
preprocess = weight.transforms()
preprocess
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %% [markdown]
# ### 6. 바이두 이미지크롤링
# - 테스트이미지셋 다운로드

# %%
# 추가설정
testset_dir = 'dataset/test'

classes = {
    'dog photo': 'dog',
    'cat photo': 'cat',
    'bird photo': 'bird'
}

num_epoch = 5
lr = 0.001

# %%
# 테스트이미지 폴더
# for keyword, class_name in classes.items():
#     save_dir = os.path.join(testset_dir, class_name)
#     os.makedirs(save_dir, exist_ok=True)

#     crawler = BaiduImageCrawler(
#         storage={'root_dir': save_dir}
#     )

#     crawler.crawl(
#         keyword=keyword,
#         max_num=150
#     )

# %% [markdown]
# ### 7. test 데이터셋 불러오기

# %%
test_dataset = ImageFolder(
    root=testset_dir,
    transform=preprocess
)
test_dataset.classes
# Out:
# ['bird', 'cat', 'dog']

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False
)

# %% [markdown]
# ### 8. test 정확도 확인

# %%
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predict = torch.max(outputs, 1)

        correct += (predict == labels).sum().item()
        total += labels.size(0)

test_acc = correct / total

print(f'테스트 정확도 : {test_acc:.4f}')
# Out:
# 테스트 정확도 : 0.9357

# %% [markdown]
# ### 9. 실제/예측값 출력

# %%
class_names = test_dataset.classes

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        prob = torch.softmax(outputs, dim=1)
        confidence, predict = torch.max(prob, 1)

        for i in range(len(labels)):
            true_label = class_names[labels[i].item()]
            pred_label = class_names[predict[i].item()]
            conf = confidence[i].item()

            print(f'실제 : {true_label} / 예측 : {pred_label} / 확률 : {conf:.4f}')
# Out:
# 실제 : bird / 예측 : bird / 확률 : 0.6514
# 실제 : bird / 예측 : bird / 확률 : 0.9549
# 실제 : bird / 예측 : bird / 확률 : 0.6732
# 실제 : bird / 예측 : bird / 확률 : 0.5060
# 실제 : bird / 예측 : bird / 확률 : 0.6966
# 실제 : bird / 예측 : bird / 확률 : 0.9222
# 실제 : bird / 예측 : bird / 확률 : 0.9648
# 실제 : bird / 예측 : bird / 확률 : 0.9561
# 실제 : bird / 예측 : bird / 확률 : 0.9622
# 실제 : bird / 예측 : bird / 확률 : 0.8288
# 실제 : bird / 예측 : bird / 확률 : 0.9424
# 실제 : bird / 예측 : bird / 확률 : 0.7866
# 실제 : bird / 예측 : bird / 확률 : 0.9213
# 실제 : bird / 예측 : bird / 확률 : 0.9012
# 실제 : bird / 예측 : bird / 확률 : 0.5536
# 실제 : bird / 예측 : bird / 확률 : 0.9744
# 실제 : bird / 예측 : bird / 확률 : 0.9091
# 실제 : bird / 예측 : bird / 확률 : 0.7549
# 실제 : bird / 예측 : bird / 확률 : 0.9738
# 실제 : bird / 예측 : bird / 확률 : 0.9552
# 실제 : bird / 예측 : bird / 확률 : 0.8208
# 실제 : bird / 예측 : bird / 확률 : 0.7706
# 실제 : bird / 예측 : bird / 확률 : 0.7852
# 실제 : bird / 예측 : bird / 확률 : 0.9514
# 실제 : bird / 예측 : bird / 확률 : 0.7937
# 실제 : bird / 예측 : bird / 확률 : 0.8790
# 실제 : bird / 예측 : bird / 확률 : 0.6955
# 실제 : bird / 예측 : bird / 확률 : 0.9273
# 실제 : bird / 예측 : bird / 확률 : 0.6888
# 실제 : bird / 예측 : bird / 확률 : 0.6158
# 실제 : bird / 예측 : bird / 확률 : 0.7179
# 실제 : bird / 예측 : bird / 확률 : 0.7433
# 실제 : bird / 예측 : bird / 확률 : 0.9261
# 실제 : bird / 예측 : bird / 확률 : 0.8577
# 실제 : bird / 예측 : bird / 확률 : 0.9635
# 실제 : bird / 예측 : bird / 확률 : 0.9795
# 실제 : bird / 예측 : bird / 확률 : 0.5553
# 실제 : bird / 예측 : bird / 확률 : 0.7165
# 실제 : bird / 예측 : bird / 확률 : 0.9011
# 실제 : bird / 예측 : bird / 확률 : 0.8009
# 실제 : bird / 예측 : bird / 확률 : 0.6254
# 실제 : bird / 예측 : bird / 확률 : 0.7435
# 실제 : bird / 예측 : bird / 확률 : 0.6214
# 실제 : bird / 예측 : dog / 확률 : 0.6135
# 실제 : bird / 예측 : cat / 확률 : 0.4709
# 실제 : bird / 예측 : bird / 확률 : 0.7136
# 실제 : bird / 예측 : bird / 확률 : 0.8685
# 실제 : bird / 예측 : bird / 확률 : 0.9674
# 실제 : bird / 예측 : bird / 확률 : 0.8829
# 실제 : bird / 예측 : bird / 확률 : 0.7115
# 실제 : bird / 예측 : bird / 확률 : 0.9606
# 실제 : bird / 예측 : cat / 확률 : 0.4191
# 실제 : bird / 예측 : bird / 확률 : 0.8602
# 실제 : bird / 예측 : bird / 확률 : 0.9183
# 실제 : bird / 예측 : bird / 확률 : 0.9751
# 실제 : bird / 예측 : bird / 확률 : 0.9562
# 실제 : bird / 예측 : bird / 확률 : 0.9368
# 실제 : bird / 예측 : bird / 확률 : 0.5251
# 실제 : bird / 예측 : bird / 확률 : 0.7149
# 실제 : bird / 예측 : bird / 확률 : 0.9848
# 실제 : bird / 예측 : bird / 확률 : 0.9124
# 실제 : bird / 예측 : bird / 확률 : 0.9136
# 실제 : bird / 예측 : bird / 확률 : 0.9607
# 실제 : bird / 예측 : bird / 확률 : 0.9512
# 실제 : bird / 예측 : dog / 확률 : 0.3749
# 실제 : bird / 예측 : bird / 확률 : 0.8920
# 실제 : bird / 예측 : bird / 확률 : 0.6840
# 실제 : bird / 예측 : bird / 확률 : 0.8402
# 실제 : bird / 예측 : bird / 확률 : 0.3892
# 실제 : cat / 예측 : cat / 확률 : 0.8113
# 실제 : cat / 예측 : cat / 확률 : 0.9531
# 실제 : cat / 예측 : cat / 확률 : 0.9352
# 실제 : cat / 예측 : cat / 확률 : 0.9250
# 실제 : cat / 예측 : cat / 확률 : 0.5071
# 실제 : cat / 예측 : cat / 확률 : 0.7981
# 실제 : cat / 예측 : cat / 확률 : 0.8689
# 실제 : cat / 예측 : cat / 확률 : 0.6518
# 실제 : cat / 예측 : cat / 확률 : 0.9592
# 실제 : cat / 예측 : cat / 확률 : 0.8306
# 실제 : cat / 예측 : cat / 확률 : 0.6405
# 실제 : cat / 예측 : cat / 확률 : 0.9562
# 실제 : cat / 예측 : cat / 확률 : 0.8791
# 실제 : cat / 예측 : cat / 확률 : 0.5831
# 실제 : cat / 예측 : cat / 확률 : 0.6297
# 실제 : cat / 예측 : cat / 확률 : 0.8972
# 실제 : cat / 예측 : cat / 확률 : 0.8678
# 실제 : cat / 예측 : cat / 확률 : 0.8242
# 실제 : cat / 예측 : cat / 확률 : 0.9812
# 실제 : cat / 예측 : dog / 확률 : 0.5710
# 실제 : cat / 예측 : cat / 확률 : 0.8546
# 실제 : cat / 예측 : cat / 확률 : 0.7831
# 실제 : cat / 예측 : cat / 확률 : 0.9830
# 실제 : cat / 예측 : cat / 확률 : 0.8923
# 실제 : cat / 예측 : cat / 확률 : 0.8146
# 실제 : cat / 예측 : cat / 확률 : 0.8197
# 실제 : cat / 예측 : cat / 확률 : 0.7315
# 실제 : cat / 예측 : cat / 확률 : 0.6400
# 실제 : cat / 예측 : cat / 확률 : 0.8846
# 실제 : cat / 예측 : cat / 확률 : 0.5831
# 실제 : cat / 예측 : cat / 확률 : 0.5302
# 실제 : cat / 예측 : cat / 확률 : 0.8060
# 실제 : cat / 예측 : cat / 확률 : 0.6802
# 실제 : cat / 예측 : cat / 확률 : 0.8531
# 실제 : cat / 예측 : cat / 확률 : 0.8324
# 실제 : cat / 예측 : cat / 확률 : 0.9075
# 실제 : cat / 예측 : cat / 확률 : 0.9051
# 실제 : cat / 예측 : cat / 확률 : 0.9138
# 실제 : cat / 예측 : cat / 확률 : 0.8735
# 실제 : cat / 예측 : cat / 확률 : 0.8406
# 실제 : cat / 예측 : cat / 확률 : 0.8128
# 실제 : cat / 예측 : cat / 확률 : 0.8680
# 실제 : cat / 예측 : dog / 확률 : 0.7340
# 실제 : cat / 예측 : cat / 확률 : 0.6898
# 실제 : cat / 예측 : cat / 확률 : 0.8498
# 실제 : cat / 예측 : cat / 확률 : 0.8091
# 실제 : cat / 예측 : cat / 확률 : 0.8130
# 실제 : cat / 예측 : cat / 확률 : 0.7232
# 실제 : cat / 예측 : cat / 확률 : 0.8543
# 실제 : cat / 예측 : cat / 확률 : 0.8574
# 실제 : cat / 예측 : cat / 확률 : 0.9356
# 실제 : cat / 예측 : cat / 확률 : 0.8242
# 실제 : cat / 예측 : cat / 확률 : 0.9047
# 실제 : cat / 예측 : cat / 확률 : 0.7698
# 실제 : cat / 예측 : cat / 확률 : 0.7623
# 실제 : cat / 예측 : cat / 확률 : 0.7862
# 실제 : cat / 예측 : dog / 확률 : 0.3749
# 실제 : cat / 예측 : cat / 확률 : 0.7971
# 실제 : cat / 예측 : cat / 확률 : 0.8089
# 실제 : cat / 예측 : cat / 확률 : 0.8197
# 실제 : cat / 예측 : cat / 확률 : 0.9598
# 실제 : cat / 예측 : cat / 확률 : 0.7149
# 실제 : cat / 예측 : cat / 확률 : 0.9184
# 실제 : cat / 예측 : cat / 확률 : 0.9135
# 실제 : cat / 예측 : cat / 확률 : 0.8350
# 실제 : cat / 예측 : cat / 확률 : 0.8059
# 실제 : cat / 예측 : cat / 확률 : 0.8924
# 실제 : cat / 예측 : cat / 확률 : 0.7969
# 실제 : cat / 예측 : cat / 확률 : 0.8171
# 실제 : cat / 예측 : cat / 확률 : 0.8894
# 실제 : cat / 예측 : cat / 확률 : 0.5252
# 실제 : cat / 예측 : dog / 확률 : 0.5848
# 실제 : cat / 예측 : cat / 확률 : 0.6775
# 실제 : cat / 예측 : cat / 확률 : 0.7490
# 실제 : cat / 예측 : cat / 확률 : 0.9547
# 실제 : cat / 예측 : cat / 확률 : 0.9585
# 실제 : cat / 예측 : dog / 확률 : 0.7443
# 실제 : cat / 예측 : cat / 확률 : 0.7432
# 실제 : cat / 예측 : cat / 확률 : 0.7948
# 실제 : cat / 예측 : cat / 확률 : 0.5656
# 실제 : cat / 예측 : cat / 확률 : 0.9632
# 실제 : cat / 예측 : cat / 확률 : 0.8865
# 실제 : cat / 예측 : cat / 확률 : 0.8650
# 실제 : cat / 예측 : cat / 확률 : 0.8904
# 실제 : cat / 예측 : cat / 확률 : 0.6794
# 실제 : cat / 예측 : cat / 확률 : 0.5123
# 실제 : cat / 예측 : cat / 확률 : 0.4396
# 실제 : cat / 예측 : cat / 확률 : 0.8034
# 실제 : cat / 예측 : dog / 확률 : 0.4575
# 실제 : cat / 예측 : cat / 확률 : 0.9686
# 실제 : dog / 예측 : dog / 확률 : 0.4421
# 실제 : dog / 예측 : dog / 확률 : 0.8320
# 실제 : dog / 예측 : dog / 확률 : 0.6732
# 실제 : dog / 예측 : dog / 확률 : 0.8365
# 실제 : dog / 예측 : dog / 확률 : 0.8215
# 실제 : dog / 예측 : dog / 확률 : 0.5611
# 실제 : dog / 예측 : dog / 확률 : 0.8836
# 실제 : dog / 예측 : dog / 확률 : 0.6195
# 실제 : dog / 예측 : dog / 확률 : 0.7952
# 실제 : dog / 예측 : dog / 확률 : 0.7307
# 실제 : dog / 예측 : dog / 확률 : 0.5301
# 실제 : dog / 예측 : dog / 확률 : 0.8000
# 실제 : dog / 예측 : dog / 확률 : 0.6780
# 실제 : dog / 예측 : dog / 확률 : 0.5727
# 실제 : dog / 예측 : dog / 확률 : 0.6819
# 실제 : dog / 예측 : dog / 확률 : 0.9334
# 실제 : dog / 예측 : dog / 확률 : 0.8984
# 실제 : dog / 예측 : dog / 확률 : 0.7144
# 실제 : dog / 예측 : dog / 확률 : 0.5759
# 실제 : dog / 예측 : dog / 확률 : 0.8573
# 실제 : dog / 예측 : dog / 확률 : 0.9610
# 실제 : dog / 예측 : dog / 확률 : 0.8126
# 실제 : dog / 예측 : dog / 확률 : 0.8577
# 실제 : dog / 예측 : cat / 확률 : 0.4511
# 실제 : dog / 예측 : dog / 확률 : 0.7540
# 실제 : dog / 예측 : dog / 확률 : 0.8855
# 실제 : dog / 예측 : dog / 확률 : 0.6927
# 실제 : dog / 예측 : dog / 확률 : 0.7867
# 실제 : dog / 예측 : dog / 확률 : 0.6392
# 실제 : dog / 예측 : dog / 확률 : 0.8020
# 실제 : dog / 예측 : dog / 확률 : 0.7547
# 실제 : dog / 예측 : dog / 확률 : 0.7533
# 실제 : dog / 예측 : dog / 확률 : 0.9143
# 실제 : dog / 예측 : dog / 확률 : 0.8053
# 실제 : dog / 예측 : dog / 확률 : 0.7440
# 실제 : dog / 예측 : dog / 확률 : 0.6678
# 실제 : dog / 예측 : dog / 확률 : 0.6874
# 실제 : dog / 예측 : dog / 확률 : 0.8316
# 실제 : dog / 예측 : dog / 확률 : 0.7274
# 실제 : dog / 예측 : dog / 확률 : 0.7619
# 실제 : dog / 예측 : dog / 확률 : 0.6609
# 실제 : dog / 예측 : dog / 확률 : 0.9436
# 실제 : dog / 예측 : dog / 확률 : 0.8992
# 실제 : dog / 예측 : dog / 확률 : 0.6630
# 실제 : dog / 예측 : dog / 확률 : 0.8329
# 실제 : dog / 예측 : dog / 확률 : 0.6682
# 실제 : dog / 예측 : dog / 확률 : 0.6598
# 실제 : dog / 예측 : dog / 확률 : 0.6757
# 실제 : dog / 예측 : dog / 확률 : 0.8370
# 실제 : dog / 예측 : dog / 확률 : 0.7737
# 실제 : dog / 예측 : dog / 확률 : 0.5999
# 실제 : dog / 예측 : dog / 확률 : 0.7461
# 실제 : dog / 예측 : dog / 확률 : 0.6951
# 실제 : dog / 예측 : dog / 확률 : 0.6436
# 실제 : dog / 예측 : dog / 확률 : 0.7370
# 실제 : dog / 예측 : dog / 확률 : 0.8958
# 실제 : dog / 예측 : dog / 확률 : 0.7013
# 실제 : dog / 예측 : dog / 확률 : 0.7113
# 실제 : dog / 예측 : dog / 확률 : 0.5918
# 실제 : dog / 예측 : dog / 확률 : 0.6285
# 실제 : dog / 예측 : dog / 확률 : 0.9447
# 실제 : dog / 예측 : dog / 확률 : 0.7468
# 실제 : dog / 예측 : dog / 확률 : 0.7692
# 실제 : dog / 예측 : dog / 확률 : 0.4826
# 실제 : dog / 예측 : dog / 확률 : 0.6216
# 실제 : dog / 예측 : dog / 확률 : 0.8010
# 실제 : dog / 예측 : dog / 확률 : 0.8810
# 실제 : dog / 예측 : dog / 확률 : 0.9129
# 실제 : dog / 예측 : dog / 확률 : 0.8472
# 실제 : dog / 예측 : dog / 확률 : 0.8297
# 실제 : dog / 예측 : dog / 확률 : 0.8095
# 실제 : dog / 예측 : dog / 확률 : 0.8210
# 실제 : dog / 예측 : dog / 확률 : 0.8662
# 실제 : dog / 예측 : dog / 확률 : 0.8395
# 실제 : dog / 예측 : dog / 확률 : 0.8403
# 실제 : dog / 예측 : dog / 확률 : 0.8865
# 실제 : dog / 예측 : dog / 확률 : 0.8125
# 실제 : dog / 예측 : dog / 확률 : 0.8756
# 실제 : dog / 예측 : dog / 확률 : 0.7558
# 실제 : dog / 예측 : dog / 확률 : 0.8851
# 실제 : dog / 예측 : dog / 확률 : 0.7491
# 실제 : dog / 예측 : cat / 확률 : 0.4060
# 실제 : dog / 예측 : dog / 확률 : 0.7952
# 실제 : dog / 예측 : dog / 확률 : 0.8805
# 실제 : dog / 예측 : dog / 확률 : 0.7306
# 실제 : dog / 예측 : dog / 확률 : 0.7836
# 실제 : dog / 예측 : dog / 확률 : 0.8910
# 실제 : dog / 예측 : dog / 확률 : 0.7533
# 실제 : dog / 예측 : dog / 확률 : 0.9692
# 실제 : dog / 예측 : dog / 확률 : 0.8251
# 실제 : dog / 예측 : dog / 확률 : 0.9257
# 실제 : dog / 예측 : dog / 확률 : 0.8348
# 실제 : dog / 예측 : dog / 확률 : 0.7377
# 실제 : dog / 예측 : dog / 확률 : 0.9489
# 실제 : dog / 예측 : dog / 확률 : 0.9046
# 실제 : dog / 예측 : dog / 확률 : 0.6280
# 실제 : dog / 예측 : dog / 확률 : 0.8318
# 실제 : dog / 예측 : dog / 확률 : 0.7307
# 실제 : dog / 예측 : dog / 확률 : 0.9428
# 실제 : dog / 예측 : dog / 확률 : 0.7794
# 실제 : dog / 예측 : dog / 확률 : 0.8829
# 실제 : dog / 예측 : dog / 확률 : 0.7511
# 실제 : dog / 예측 : dog / 확률 : 0.9582
# 실제 : dog / 예측 : dog / 확률 : 0.8619
# 실제 : dog / 예측 : dog / 확률 : 0.5819
# 실제 : dog / 예측 : dog / 확률 : 0.8698
# 실제 : dog / 예측 : dog / 확률 : 0.7715
# 실제 : dog / 예측 : dog / 확률 : 0.8515
# 실제 : dog / 예측 : dog / 확률 : 0.7485
# 실제 : dog / 예측 : dog / 확률 : 0.7364
# 실제 : dog / 예측 : dog / 확률 : 0.8448
# 실제 : dog / 예측 : dog / 확률 : 0.9157
# 실제 : dog / 예측 : dog / 확률 : 0.8312
# 실제 : dog / 예측 : dog / 확률 : 0.6885
# 실제 : dog / 예측 : dog / 확률 : 0.8993
# 실제 : dog / 예측 : dog / 확률 : 0.8691
# 실제 : dog / 예측 : dog / 확률 : 0.8826
# 실제 : dog / 예측 : dog / 확률 : 0.8701
# 실제 : dog / 예측 : dog / 확률 : 0.8769
# 실제 : dog / 예측 : dog / 확률 : 0.8388
# 실제 : dog / 예측 : dog / 확률 : 0.8723
# 실제 : dog / 예측 : dog / 확률 : 0.9163
# 실제 : dog / 예측 : dog / 확률 : 0.6804
# 실제 : dog / 예측 : dog / 확률 : 0.5118
# 실제 : dog / 예측 : dog / 확률 : 0.7142
# 실제 : dog / 예측 : dog / 확률 : 0.6662
# 실제 : dog / 예측 : dog / 확률 : 0.5714
# 실제 : dog / 예측 : dog / 확률 : 0.7102
# 실제 : dog / 예측 : dog / 확률 : 0.7618
# 실제 : dog / 예측 : dog / 확률 : 0.5063
# 실제 : dog / 예측 : dog / 확률 : 0.6243
# 실제 : dog / 예측 : dog / 확률 : 0.7181
# 실제 : dog / 예측 : cat / 확률 : 0.5107
# 실제 : dog / 예측 : dog / 확률 : 0.8447
# 실제 : dog / 예측 : dog / 확률 : 0.6503
# 실제 : dog / 예측 : dog / 확률 : 0.8128
# 실제 : dog / 예측 : dog / 확률 : 0.6697
# 실제 : dog / 예측 : dog / 확률 : 0.6197
# 실제 : dog / 예측 : dog / 확률 : 0.6125
# 실제 : dog / 예측 : cat / 확률 : 0.5157
# 실제 : dog / 예측 : dog / 확률 : 0.5258
# 실제 : dog / 예측 : dog / 확률 : 0.8100
# 실제 : dog / 예측 : dog / 확률 : 0.8680
# 실제 : dog / 예측 : dog / 확률 : 0.8082
# 실제 : dog / 예측 : dog / 확률 : 0.5972
# 실제 : dog / 예측 : dog / 확률 : 0.8769
# 실제 : dog / 예측 : cat / 확률 : 0.5279
# 실제 : dog / 예측 : dog / 확률 : 0.7546
# 실제 : dog / 예측 : dog / 확률 : 0.5208
# 실제 : dog / 예측 : dog / 확률 : 0.8707
# 실제 : dog / 예측 : dog / 확률 : 0.8220
# 실제 : dog / 예측 : dog / 확률 : 0.5439
# 실제 : dog / 예측 : dog / 확률 : 0.7930
# 실제 : dog / 예측 : dog / 확률 : 0.5875
# 실제 : dog / 예측 : dog / 확률 : 0.6232
# 실제 : dog / 예측 : dog / 확률 : 0.7227
# 실제 : dog / 예측 : dog / 확률 : 0.7163
# 실제 : dog / 예측 : bird / 확률 : 0.5914
# 실제 : dog / 예측 : dog / 확률 : 0.7510
# 실제 : dog / 예측 : dog / 확률 : 0.6679
# 실제 : dog / 예측 : dog / 확률 : 0.7111
# 실제 : dog / 예측 : dog / 확률 : 0.6432
# 실제 : dog / 예측 : dog / 확률 : 0.6728
# 실제 : dog / 예측 : dog / 확률 : 0.4542
# 실제 : dog / 예측 : dog / 확률 : 0.4147
# 실제 : dog / 예측 : dog / 확률 : 0.5948
# 실제 : dog / 예측 : dog / 확률 : 0.6656
# 실제 : dog / 예측 : dog / 확률 : 0.9071
# 실제 : dog / 예측 : dog / 확률 : 0.8024
# 실제 : dog / 예측 : dog / 확률 : 0.9544
# 실제 : dog / 예측 : dog / 확률 : 0.8545
# 실제 : dog / 예측 : dog / 확률 : 0.6997
# 실제 : dog / 예측 : dog / 확률 : 0.8487
# 실제 : dog / 예측 : dog / 확률 : 0.8405
# 실제 : dog / 예측 : dog / 확률 : 0.7052
# 실제 : dog / 예측 : dog / 확률 : 0.5794
# 실제 : dog / 예측 : dog / 확률 : 0.6643
# 실제 : dog / 예측 : dog / 확률 : 0.8642
# 실제 : dog / 예측 : dog / 확률 : 0.4903
# 실제 : dog / 예측 : dog / 확률 : 0.7497
# 실제 : dog / 예측 : bird / 확률 : 0.3727
# 실제 : dog / 예측 : dog / 확률 : 0.5228
# 실제 : dog / 예측 : cat / 확률 : 0.5153
# 실제 : dog / 예측 : dog / 확률 : 0.5258
# 실제 : dog / 예측 : dog / 확률 : 0.4842
# 실제 : dog / 예측 : dog / 확률 : 0.9423
# 실제 : dog / 예측 : dog / 확률 : 0.7076
# 실제 : dog / 예측 : dog / 확률 : 0.7414
# 실제 : dog / 예측 : dog / 확률 : 0.7078
# 실제 : dog / 예측 : dog / 확률 : 0.6957
# 실제 : dog / 예측 : dog / 확률 : 0.4741
# 실제 : dog / 예측 : dog / 확률 : 0.6712
# 실제 : dog / 예측 : dog / 확률 : 0.6940
# 실제 : dog / 예측 : dog / 확률 : 0.6837
# 실제 : dog / 예측 : dog / 확률 : 0.5924
# 실제 : dog / 예측 : dog / 확률 : 0.6674
# 실제 : dog / 예측 : dog / 확률 : 0.5853
# 실제 : dog / 예측 : cat / 확률 : 0.4221
# 실제 : dog / 예측 : dog / 확률 : 0.5909
# 실제 : dog / 예측 : dog / 확률 : 0.4027
# 실제 : dog / 예측 : dog / 확률 : 0.8411
# 실제 : dog / 예측 : cat / 확률 : 0.5141
# 실제 : dog / 예측 : dog / 확률 : 0.9034
# 실제 : dog / 예측 : dog / 확률 : 0.6973
# 실제 : dog / 예측 : dog / 확률 : 0.5284
# 실제 : dog / 예측 : dog / 확률 : 0.7268
# 실제 : dog / 예측 : dog / 확률 : 0.7695
# 실제 : dog / 예측 : dog / 확률 : 0.6841
# 실제 : dog / 예측 : dog / 확률 : 0.7365
# 실제 : dog / 예측 : dog / 확률 : 0.8699
# 실제 : dog / 예측 : dog / 확률 : 0.8170
# 실제 : dog / 예측 : dog / 확률 : 0.8991
# 실제 : dog / 예측 : dog / 확률 : 0.7512
# 실제 : dog / 예측 : dog / 확률 : 0.8794
# 실제 : dog / 예측 : dog / 확률 : 0.5309
# 실제 : dog / 예측 : dog / 확률 : 0.7204
# 실제 : dog / 예측 : dog / 확률 : 0.8558
# 실제 : dog / 예측 : dog / 확률 : 0.6645
# 실제 : dog / 예측 : dog / 확률 : 0.9475
# 실제 : dog / 예측 : dog / 확률 : 0.7043
# 실제 : dog / 예측 : dog / 확률 : 0.6383
# 실제 : dog / 예측 : dog / 확률 : 0.6891
# 실제 : dog / 예측 : bird / 확률 : 0.4647
# 실제 : dog / 예측 : dog / 확률 : 0.6423
# 실제 : dog / 예측 : dog / 확률 : 0.7899
# 실제 : dog / 예측 : dog / 확률 : 0.7792
# 실제 : dog / 예측 : cat / 확률 : 0.5483
# 실제 : dog / 예측 : dog / 확률 : 0.7791
# 실제 : dog / 예측 : dog / 확률 : 0.8576
# 실제 : dog / 예측 : cat / 확률 : 0.6585
# 실제 : dog / 예측 : dog / 확률 : 0.6838
# 실제 : dog / 예측 : cat / 확률 : 0.6204
# 실제 : dog / 예측 : dog / 확률 : 0.7751
# 실제 : dog / 예측 : dog / 확률 : 0.6616
# 실제 : dog / 예측 : dog / 확률 : 0.6750
# 실제 : dog / 예측 : dog / 확률 : 0.6201
# 실제 : dog / 예측 : dog / 확률 : 0.7966
# 실제 : dog / 예측 : dog / 확률 : 0.8859
# 실제 : dog / 예측 : dog / 확률 : 0.8296
# 실제 : dog / 예측 : dog / 확률 : 0.8446
# 실제 : dog / 예측 : dog / 확률 : 0.7871
# 실제 : dog / 예측 : dog / 확률 : 0.8119
# 실제 : dog / 예측 : dog / 확률 : 0.8441
# 실제 : dog / 예측 : dog / 확률 : 0.7741
# 실제 : dog / 예측 : dog / 확률 : 0.7122
# 실제 : dog / 예측 : dog / 확률 : 0.7098
# 실제 : dog / 예측 : dog / 확률 : 0.5467
# 실제 : dog / 예측 : cat / 확률 : 0.3590
# 실제 : dog / 예측 : bird / 확률 : 0.4729
# 실제 : dog / 예측 : dog / 확률 : 0.6294
# 실제 : dog / 예측 : dog / 확률 : 0.9510
# 실제 : dog / 예측 : dog / 확률 : 0.5847
# 실제 : dog / 예측 : dog / 확률 : 0.8076
# 실제 : dog / 예측 : dog / 확률 : 0.8124
# 실제 : dog / 예측 : dog / 확률 : 0.8208
# 실제 : dog / 예측 : dog / 확률 : 0.9540
# 실제 : dog / 예측 : dog / 확률 : 0.9023
# 실제 : dog / 예측 : dog / 확률 : 0.7689
# 실제 : dog / 예측 : dog / 확률 : 0.8351
# 실제 : dog / 예측 : dog / 확률 : 0.8210
# 실제 : dog / 예측 : dog / 확률 : 0.7624
# 실제 : dog / 예측 : dog / 확률 : 0.9171
# 실제 : dog / 예측 : dog / 확률 : 0.8794
# 실제 : dog / 예측 : dog / 확률 : 0.4112
# 실제 : dog / 예측 : dog / 확률 : 0.6810
# 실제 : dog / 예측 : dog / 확률 : 0.4758
# 실제 : dog / 예측 : dog / 확률 : 0.7873
# 실제 : dog / 예측 : dog / 확률 : 0.8893
# 실제 : dog / 예측 : dog / 확률 : 0.7071
# 실제 : dog / 예측 : cat / 확률 : 0.4758
# 실제 : dog / 예측 : dog / 확률 : 0.4612
# 실제 : dog / 예측 : dog / 확률 : 0.8543
# 실제 : dog / 예측 : dog / 확률 : 0.5595
# 실제 : dog / 예측 : dog / 확률 : 0.5359
# 실제 : dog / 예측 : dog / 확률 : 0.8958
# 실제 : dog / 예측 : dog / 확률 : 0.7367
# 실제 : dog / 예측 : dog / 확률 : 0.8680
# 실제 : dog / 예측 : dog / 확률 : 0.7719
# 실제 : dog / 예측 : dog / 확률 : 0.9400
# 실제 : dog / 예측 : dog / 확률 : 0.5293
# 실제 : dog / 예측 : dog / 확률 : 0.6526
# 실제 : dog / 예측 : dog / 확률 : 0.7525
# 실제 : dog / 예측 : dog / 확률 : 0.7598
# 실제 : dog / 예측 : dog / 확률 : 0.7537
# 실제 : dog / 예측 : dog / 확률 : 0.7992
# 실제 : dog / 예측 : dog / 확률 : 0.6054
# 실제 : dog / 예측 : dog / 확률 : 0.6246
# 실제 : dog / 예측 : dog / 확률 : 0.7732
# 실제 : dog / 예측 : dog / 확률 : 0.7162
# 실제 : dog / 예측 : dog / 확률 : 0.8145
# 실제 : dog / 예측 : dog / 확률 : 0.5435
# 실제 : dog / 예측 : dog / 확률 : 0.8445
# 실제 : dog / 예측 : dog / 확률 : 0.8007
# 실제 : dog / 예측 : dog / 확률 : 0.7967
# 실제 : dog / 예측 : dog / 확률 : 0.6169
# 실제 : dog / 예측 : cat / 확률 : 0.3974
# 실제 : dog / 예측 : dog / 확률 : 0.6181
# 실제 : dog / 예측 : dog / 확률 : 0.7759
# 실제 : dog / 예측 : dog / 확률 : 0.8707
# 실제 : dog / 예측 : dog / 확률 : 0.5566
# 실제 : dog / 예측 : dog / 확률 : 0.6033
# 실제 : dog / 예측 : dog / 확률 : 0.6134
# 실제 : dog / 예측 : dog / 확률 : 0.6665
# 실제 : dog / 예측 : dog / 확률 : 0.4743
# 실제 : dog / 예측 : dog / 확률 : 0.8885
# 실제 : dog / 예측 : dog / 확률 : 0.6992
# 실제 : dog / 예측 : dog / 확률 : 0.8133
# 실제 : dog / 예측 : dog / 확률 : 0.7931
# 실제 : dog / 예측 : dog / 확률 : 0.6077
# 실제 : dog / 예측 : dog / 확률 : 0.8443
# 실제 : dog / 예측 : dog / 확률 : 0.4532
# 실제 : dog / 예측 : dog / 확률 : 0.6836
# 실제 : dog / 예측 : dog / 확률 : 0.6929
# 실제 : dog / 예측 : dog / 확률 : 0.8462
# 실제 : dog / 예측 : dog / 확률 : 0.6417
# 실제 : dog / 예측 : dog / 확률 : 0.7440
# 실제 : dog / 예측 : dog / 확률 : 0.7199
# 실제 : dog / 예측 : dog / 확률 : 0.6635
# 실제 : dog / 예측 : dog / 확률 : 0.8060
# 실제 : dog / 예측 : dog / 확률 : 0.8115
# 실제 : dog / 예측 : dog / 확률 : 0.4684
# 실제 : dog / 예측 : dog / 확률 : 0.8779
# 실제 : dog / 예측 : dog / 확률 : 0.6684
# 실제 : dog / 예측 : dog / 확률 : 0.5494
# 실제 : dog / 예측 : dog / 확률 : 0.5908
# 실제 : dog / 예측 : dog / 확률 : 0.5827
# 실제 : dog / 예측 : dog / 확률 : 0.8388
# 실제 : dog / 예측 : dog / 확률 : 0.6729
# 실제 : dog / 예측 : dog / 확률 : 0.6768
# 실제 : dog / 예측 : dog / 확률 : 0.7542
# 실제 : dog / 예측 : dog / 확률 : 0.6723
# 실제 : dog / 예측 : cat / 확률 : 0.5249
# 실제 : dog / 예측 : dog / 확률 : 0.4763
# 실제 : dog / 예측 : dog / 확률 : 0.8090
# 실제 : dog / 예측 : dog / 확률 : 0.4913
# 실제 : dog / 예측 : dog / 확률 : 0.7558
# 실제 : dog / 예측 : dog / 확률 : 0.7829
# 실제 : dog / 예측 : dog / 확률 : 0.8301
# 실제 : dog / 예측 : dog / 확률 : 0.4528
# 실제 : dog / 예측 : cat / 확률 : 0.7262
# 실제 : dog / 예측 : dog / 확률 : 0.7708
# 실제 : dog / 예측 : dog / 확률 : 0.5260
# 실제 : dog / 예측 : dog / 확률 : 0.7724
# 실제 : dog / 예측 : dog / 확률 : 0.6352
# 실제 : dog / 예측 : dog / 확률 : 0.4535
# 실제 : dog / 예측 : dog / 확률 : 0.4780
# 실제 : dog / 예측 : bird / 확률 : 0.4559
# 실제 : dog / 예측 : dog / 확률 : 0.5171
# 실제 : dog / 예측 : dog / 확률 : 0.6827
# 실제 : dog / 예측 : cat / 확률 : 0.7188
# 실제 : dog / 예측 : dog / 확률 : 0.7500
# 실제 : dog / 예측 : dog / 확률 : 0.8246
# 실제 : dog / 예측 : dog / 확률 : 0.9100
# 실제 : dog / 예측 : dog / 확률 : 0.6814
# 실제 : dog / 예측 : dog / 확률 : 0.5992
# 실제 : dog / 예측 : dog / 확률 : 0.7307
# 실제 : dog / 예측 : dog / 확률 : 0.6593
# 실제 : dog / 예측 : dog / 확률 : 0.7556
# 실제 : dog / 예측 : dog / 확률 : 0.7730
# 실제 : dog / 예측 : dog / 확률 : 0.8718
# 실제 : dog / 예측 : dog / 확률 : 0.7940
# 실제 : dog / 예측 : dog / 확률 : 0.9504
# 실제 : dog / 예측 : dog / 확률 : 0.5404
# 실제 : dog / 예측 : dog / 확률 : 0.6700
# 실제 : dog / 예측 : dog / 확률 : 0.8430
# 실제 : dog / 예측 : dog / 확률 : 0.6644
# 실제 : dog / 예측 : dog / 확률 : 0.8093
# 실제 : dog / 예측 : dog / 확률 : 0.9278
# 실제 : dog / 예측 : dog / 확률 : 0.8943
# 실제 : dog / 예측 : cat / 확률 : 0.4321
# 실제 : dog / 예측 : dog / 확률 : 0.7862
# 실제 : dog / 예측 : dog / 확률 : 0.8724
# 실제 : dog / 예측 : dog / 확률 : 0.7190
# 실제 : dog / 예측 : dog / 확률 : 0.4873
# 실제 : dog / 예측 : dog / 확률 : 0.9068
# 실제 : dog / 예측 : cat / 확률 : 0.8964
# 실제 : dog / 예측 : dog / 확률 : 0.5822
# 실제 : dog / 예측 : cat / 확률 : 0.5044
# 실제 : dog / 예측 : dog / 확률 : 0.8211
# 실제 : dog / 예측 : dog / 확률 : 0.7504
# 실제 : dog / 예측 : dog / 확률 : 0.6405
# 실제 : dog / 예측 : dog / 확률 : 0.6662
# 실제 : dog / 예측 : dog / 확률 : 0.3749
# 실제 : dog / 예측 : dog / 확률 : 0.4773
# 실제 : dog / 예측 : cat / 확률 : 0.4651
# 실제 : dog / 예측 : dog / 확률 : 0.7192
# 실제 : dog / 예측 : dog / 확률 : 0.9200
# 실제 : dog / 예측 : dog / 확률 : 0.6037
# 실제 : dog / 예측 : dog / 확률 : 0.7375
# 실제 : dog / 예측 : dog / 확률 : 0.7432
# 실제 : dog / 예측 : dog / 확률 : 0.8326
# 실제 : dog / 예측 : dog / 확률 : 0.8677
# 실제 : dog / 예측 : dog / 확률 : 0.6657
# 실제 : dog / 예측 : dog / 확률 : 0.7071
# 실제 : dog / 예측 : dog / 확률 : 0.8212
# 실제 : dog / 예측 : dog / 확률 : 0.7348
# 실제 : dog / 예측 : dog / 확률 : 0.6929
# 실제 : dog / 예측 : dog / 확률 : 0.5293
# 실제 : dog / 예측 : dog / 확률 : 0.8356
# 실제 : dog / 예측 : dog / 확률 : 0.9382
# 실제 : dog / 예측 : dog / 확률 : 0.6537
# 실제 : dog / 예측 : dog / 확률 : 0.7523
# 실제 : dog / 예측 : dog / 확률 : 0.7923
# 실제 : dog / 예측 : cat / 확률 : 0.4811
# 실제 : dog / 예측 : dog / 확률 : 0.7183
# 실제 : dog / 예측 : dog / 확률 : 0.6846
# 실제 : dog / 예측 : dog / 확률 : 0.7937
# 실제 : dog / 예측 : dog / 확률 : 0.7559
# 실제 : dog / 예측 : cat / 확률 : 0.5986
# 실제 : dog / 예측 : dog / 확률 : 0.6698
# 실제 : dog / 예측 : dog / 확률 : 0.7250
# 실제 : dog / 예측 : dog / 확률 : 0.6862
# 실제 : dog / 예측 : dog / 확률 : 0.6716
# 실제 : dog / 예측 : dog / 확률 : 0.4725
# 실제 : dog / 예측 : dog / 확률 : 0.7181
# 실제 : dog / 예측 : dog / 확률 : 0.7598
# 실제 : dog / 예측 : dog / 확률 : 0.5286
# 실제 : dog / 예측 : dog / 확률 : 0.8350
# 실제 : dog / 예측 : dog / 확률 : 0.7038
# 실제 : dog / 예측 : dog / 확률 : 0.4687
# 실제 : dog / 예측 : dog / 확률 : 0.5425
# 실제 : dog / 예측 : dog / 확률 : 0.5589
# 실제 : dog / 예측 : dog / 확률 : 0.4519
# 실제 : dog / 예측 : dog / 확률 : 0.7362
# 실제 : dog / 예측 : dog / 확률 : 0.7056
# 실제 : dog / 예측 : dog / 확률 : 0.5459
# 실제 : dog / 예측 : dog / 확률 : 0.5768
# 실제 : dog / 예측 : dog / 확률 : 0.4241
# 실제 : dog / 예측 : dog / 확률 : 0.5912
# 실제 : dog / 예측 : cat / 확률 : 0.5570
# 실제 : dog / 예측 : dog / 확률 : 0.4607
# 실제 : dog / 예측 : cat / 확률 : 0.4920
# 실제 : dog / 예측 : cat / 확률 : 0.5670
# 실제 : dog / 예측 : dog / 확률 : 0.5215
# 실제 : dog / 예측 : dog / 확률 : 0.5689
# 실제 : dog / 예측 : dog / 확률 : 0.6420
# 실제 : dog / 예측 : dog / 확률 : 0.6441
# 실제 : dog / 예측 : dog / 확률 : 0.4684
# 실제 : dog / 예측 : dog / 확률 : 0.8039
# 실제 : dog / 예측 : dog / 확률 : 0.6558
# 실제 : dog / 예측 : dog / 확률 : 0.4586
# 실제 : dog / 예측 : dog / 확률 : 0.4445
# 실제 : dog / 예측 : dog / 확률 : 0.5300
# 실제 : dog / 예측 : dog / 확률 : 0.7316
# 실제 : dog / 예측 : dog / 확률 : 0.4397
# 실제 : dog / 예측 : dog / 확률 : 0.8388
# 실제 : dog / 예측 : dog / 확률 : 0.9184
# 실제 : dog / 예측 : dog / 확률 : 0.8330
# 실제 : dog / 예측 : dog / 확률 : 0.7077
# 실제 : dog / 예측 : dog / 확률 : 0.7269
# 실제 : dog / 예측 : cat / 확률 : 0.6837
# 실제 : dog / 예측 : cat / 확률 : 0.5032
# 실제 : dog / 예측 : dog / 확률 : 0.6760
# 실제 : dog / 예측 : cat / 확률 : 0.4790
# 실제 : dog / 예측 : dog / 확률 : 0.6911
# 실제 : dog / 예측 : dog / 확률 : 0.6708
# 실제 : dog / 예측 : dog / 확률 : 0.7606
# 실제 : dog / 예측 : dog / 확률 : 0.6228
# 실제 : dog / 예측 : cat / 확률 : 0.4418
# 실제 : dog / 예측 : dog / 확률 : 0.8836
# 실제 : dog / 예측 : dog / 확률 : 0.8654
# 실제 : dog / 예측 : dog / 확률 : 0.9034
# 실제 : dog / 예측 : dog / 확률 : 0.4738
# 실제 : dog / 예측 : dog / 확률 : 0.8454
# 실제 : dog / 예측 : dog / 확률 : 0.8530
# 실제 : dog / 예측 : dog / 확률 : 0.7521
# 실제 : dog / 예측 : dog / 확률 : 0.7045
# 실제 : dog / 예측 : dog / 확률 : 0.7020
# 실제 : dog / 예측 : dog / 확률 : 0.9489
# 실제 : dog / 예측 : dog / 확률 : 0.6975
# 실제 : dog / 예측 : dog / 확률 : 0.7321
# 실제 : dog / 예측 : dog / 확률 : 0.5452
# 실제 : dog / 예측 : dog / 확률 : 0.8255
# 실제 : dog / 예측 : dog / 확률 : 0.7317
# 실제 : dog / 예측 : dog / 확률 : 0.6586
# 실제 : dog / 예측 : dog / 확률 : 0.7132
# 실제 : dog / 예측 : dog / 확률 : 0.6978
# 실제 : dog / 예측 : dog / 확률 : 0.6455
# 실제 : dog / 예측 : dog / 확률 : 0.5568
# 실제 : dog / 예측 : dog / 확률 : 0.6004
# 실제 : dog / 예측 : dog / 확률 : 0.7623
# 실제 : dog / 예측 : dog / 확률 : 0.7715
# 실제 : dog / 예측 : dog / 확률 : 0.7101
# 실제 : dog / 예측 : dog / 확률 : 0.5686
# 실제 : dog / 예측 : dog / 확률 : 0.4734
# 실제 : dog / 예측 : dog / 확률 : 0.5885
# 실제 : dog / 예측 : dog / 확률 : 0.8251
# 실제 : dog / 예측 : dog / 확률 : 0.8070
# 실제 : dog / 예측 : dog / 확률 : 0.7307
# 실제 : dog / 예측 : dog / 확률 : 0.7553
# 실제 : dog / 예측 : dog / 확률 : 0.7090
# 실제 : dog / 예측 : dog / 확률 : 0.5822
# 실제 : dog / 예측 : dog / 확률 : 0.8427
# 실제 : dog / 예측 : dog / 확률 : 0.7960
# 실제 : dog / 예측 : dog / 확률 : 0.8036
# 실제 : dog / 예측 : dog / 확률 : 0.6470
# 실제 : dog / 예측 : dog / 확률 : 0.8241
# 실제 : dog / 예측 : dog / 확률 : 0.8999
# 실제 : dog / 예측 : dog / 확률 : 0.7496
# 실제 : dog / 예측 : dog / 확률 : 0.6368
# 실제 : dog / 예측 : dog / 확률 : 0.5230
# 실제 : dog / 예측 : dog / 확률 : 0.5791
# 실제 : dog / 예측 : dog / 확률 : 0.6966
# 실제 : dog / 예측 : dog / 확률 : 0.9179
# 실제 : dog / 예측 : dog / 확률 : 0.7240
# 실제 : dog / 예측 : dog / 확률 : 0.7471
# 실제 : dog / 예측 : dog / 확률 : 0.7204
# 실제 : dog / 예측 : dog / 확률 : 0.7389
# 실제 : dog / 예측 : dog / 확률 : 0.7590
# 실제 : dog / 예측 : dog / 확률 : 0.7581
# 실제 : dog / 예측 : dog / 확률 : 0.8756
# 실제 : dog / 예측 : dog / 확률 : 0.7859
# 실제 : dog / 예측 : dog / 확률 : 0.7920
# 실제 : dog / 예측 : dog / 확률 : 0.7464
# 실제 : dog / 예측 : dog / 확률 : 0.7758
# 실제 : dog / 예측 : dog / 확률 : 0.8511
# 실제 : dog / 예측 : dog / 확률 : 0.8484
# 실제 : dog / 예측 : dog / 확률 : 0.6802
# 실제 : dog / 예측 : dog / 확률 : 0.8516
# 실제 : dog / 예측 : dog / 확률 : 0.7368
# 실제 : dog / 예측 : dog / 확률 : 0.8246
# 실제 : dog / 예측 : dog / 확률 : 0.7378
# 실제 : dog / 예측 : dog / 확률 : 0.9045
# 실제 : dog / 예측 : dog / 확률 : 0.8215
# 실제 : dog / 예측 : dog / 확률 : 0.6286
# 실제 : dog / 예측 : dog / 확률 : 0.7227
# 실제 : dog / 예측 : dog / 확률 : 0.6855
# 실제 : dog / 예측 : dog / 확률 : 0.6923
# 실제 : dog / 예측 : dog / 확률 : 0.7785
# 실제 : dog / 예측 : dog / 확률 : 0.8580
# 실제 : dog / 예측 : dog / 확률 : 0.7930
# 실제 : dog / 예측 : dog / 확률 : 0.8141
# 실제 : dog / 예측 : dog / 확률 : 0.6630
# 실제 : dog / 예측 : dog / 확률 : 0.8997
# 실제 : dog / 예측 : dog / 확률 : 0.9229
# 실제 : dog / 예측 : dog / 확률 : 0.7220
# 실제 : dog / 예측 : dog / 확률 : 0.7071
# 실제 : dog / 예측 : bird / 확률 : 0.4273
# 실제 : dog / 예측 : dog / 확률 : 0.6886
# 실제 : dog / 예측 : dog / 확률 : 0.4826
# 실제 : dog / 예측 : dog / 확률 : 0.8584
# 실제 : dog / 예측 : dog / 확률 : 0.5337
# 실제 : dog / 예측 : dog / 확률 : 0.6278
# 실제 : dog / 예측 : dog / 확률 : 0.4829
# 실제 : dog / 예측 : dog / 확률 : 0.8794
# 실제 : dog / 예측 : dog / 확률 : 0.7561
# 실제 : dog / 예측 : dog / 확률 : 0.8679
# 실제 : dog / 예측 : dog / 확률 : 0.6418
# 실제 : dog / 예측 : dog / 확률 : 0.5689
# 실제 : dog / 예측 : dog / 확률 : 0.6554
# 실제 : dog / 예측 : dog / 확률 : 0.6241
# 실제 : dog / 예측 : dog / 확률 : 0.9189
# 실제 : dog / 예측 : dog / 확률 : 0.6254
# 실제 : dog / 예측 : dog / 확률 : 0.9076
# 실제 : dog / 예측 : dog / 확률 : 0.5022
# 실제 : dog / 예측 : dog / 확률 : 0.8989
# 실제 : dog / 예측 : dog / 확률 : 0.5933
# 실제 : dog / 예측 : dog / 확률 : 0.8645
# 실제 : dog / 예측 : dog / 확률 : 0.7304
# 실제 : dog / 예측 : dog / 확률 : 0.7160
# 실제 : dog / 예측 : dog / 확률 : 0.8389
# 실제 : dog / 예측 : dog / 확률 : 0.9212
# 실제 : dog / 예측 : dog / 확률 : 0.5810
# 실제 : dog / 예측 : dog / 확률 : 0.8597
# 실제 : dog / 예측 : dog / 확률 : 0.6995
# 실제 : dog / 예측 : dog / 확률 : 0.7468
# 실제 : dog / 예측 : dog / 확률 : 0.9025
# 실제 : dog / 예측 : dog / 확률 : 0.6646
# 실제 : dog / 예측 : cat / 확률 : 0.6053
# 실제 : dog / 예측 : dog / 확률 : 0.9716
# 실제 : dog / 예측 : dog / 확률 : 0.5196
# 실제 : dog / 예측 : dog / 확률 : 0.9080
# 실제 : dog / 예측 : dog / 확률 : 0.8710
# 실제 : dog / 예측 : dog / 확률 : 0.5005
# 실제 : dog / 예측 : dog / 확률 : 0.6528
# 실제 : dog / 예측 : dog / 확률 : 0.7158
# 실제 : dog / 예측 : dog / 확률 : 0.5750
# 실제 : dog / 예측 : dog / 확률 : 0.7296
# 실제 : dog / 예측 : dog / 확률 : 0.5992
# 실제 : dog / 예측 : dog / 확률 : 0.7732
# 실제 : dog / 예측 : dog / 확률 : 0.4203
# 실제 : dog / 예측 : dog / 확률 : 0.6829
# 실제 : dog / 예측 : dog / 확률 : 0.7773
# 실제 : dog / 예측 : dog / 확률 : 0.8780
# 실제 : dog / 예측 : dog / 확률 : 0.4844
# 실제 : dog / 예측 : dog / 확률 : 0.5423
# 실제 : dog / 예측 : dog / 확률 : 0.8184
# 실제 : dog / 예측 : dog / 확률 : 0.8212
# 실제 : dog / 예측 : dog / 확률 : 0.7522
# 실제 : dog / 예측 : dog / 확률 : 0.4524
# 실제 : dog / 예측 : dog / 확률 : 0.5503
# 실제 : dog / 예측 : dog / 확률 : 0.4969
# 실제 : dog / 예측 : dog / 확률 : 0.4867
# 실제 : dog / 예측 : dog / 확률 : 0.6535
# 실제 : dog / 예측 : dog / 확률 : 0.5707
# 실제 : dog / 예측 : dog / 확률 : 0.5645
# 실제 : dog / 예측 : dog / 확률 : 0.7200
# 실제 : dog / 예측 : cat / 확률 : 0.5773
# 실제 : dog / 예측 : dog / 확률 : 0.5670
# 실제 : dog / 예측 : cat / 확률 : 0.6943
# 실제 : dog / 예측 : dog / 확률 : 0.6738
# 실제 : dog / 예측 : dog / 확률 : 0.6125
# 실제 : dog / 예측 : dog / 확률 : 0.7270
# 실제 : dog / 예측 : dog / 확률 : 0.6844
# 실제 : dog / 예측 : dog / 확률 : 0.8620
# 실제 : dog / 예측 : dog / 확률 : 0.7875
# 실제 : dog / 예측 : dog / 확률 : 0.5951
# 실제 : dog / 예측 : dog / 확률 : 0.8828
# 실제 : dog / 예측 : dog / 확률 : 0.9507
# 실제 : dog / 예측 : dog / 확률 : 0.7699
# 실제 : dog / 예측 : dog / 확률 : 0.8427
# 실제 : dog / 예측 : dog / 확률 : 0.6477
# 실제 : dog / 예측 : dog / 확률 : 0.7814
# 실제 : dog / 예측 : dog / 확률 : 0.7923
# 실제 : dog / 예측 : dog / 확률 : 0.8708
# 실제 : dog / 예측 : dog / 확률 : 0.7768
# 실제 : dog / 예측 : dog / 확률 : 0.7762
# 실제 : dog / 예측 : dog / 확률 : 0.8129
# 실제 : dog / 예측 : dog / 확률 : 0.7489
# 실제 : dog / 예측 : dog / 확률 : 0.4698
# 실제 : dog / 예측 : dog / 확률 : 0.7967
# 실제 : dog / 예측 : dog / 확률 : 0.7201
# 실제 : dog / 예측 : dog / 확률 : 0.7338
# 실제 : dog / 예측 : cat / 확률 : 0.4407
# 실제 : dog / 예측 : dog / 확률 : 0.5220
# 실제 : dog / 예측 : dog / 확률 : 0.7789
# 실제 : dog / 예측 : dog / 확률 : 0.8312
# 실제 : dog / 예측 : cat / 확률 : 0.4713
# 실제 : dog / 예측 : dog / 확률 : 0.8790
# 실제 : dog / 예측 : dog / 확률 : 0.8410
# 실제 : dog / 예측 : dog / 확률 : 0.8081
# 실제 : dog / 예측 : dog / 확률 : 0.7239
# 실제 : dog / 예측 : dog / 확률 : 0.5366
# 실제 : dog / 예측 : dog / 확률 : 0.8008
# 실제 : dog / 예측 : dog / 확률 : 0.4640
# 실제 : dog / 예측 : dog / 확률 : 0.7317
# 실제 : dog / 예측 : dog / 확률 : 0.7691
# 실제 : dog / 예측 : dog / 확률 : 0.8222
# 실제 : dog / 예측 : dog / 확률 : 0.6448
# 실제 : dog / 예측 : dog / 확률 : 0.5074
# 실제 : dog / 예측 : dog / 확률 : 0.6421
# 실제 : dog / 예측 : dog / 확률 : 0.5703
# 실제 : dog / 예측 : dog / 확률 : 0.7589
# 실제 : dog / 예측 : dog / 확률 : 0.6643
# 실제 : dog / 예측 : dog / 확률 : 0.7706
# 실제 : dog / 예측 : dog / 확률 : 0.4950
# 실제 : dog / 예측 : dog / 확률 : 0.6593
# 실제 : dog / 예측 : dog / 확률 : 0.5242
# 실제 : dog / 예측 : cat / 확률 : 0.5039
# 실제 : dog / 예측 : dog / 확률 : 0.7367
# 실제 : dog / 예측 : dog / 확률 : 0.7189
# 실제 : dog / 예측 : dog / 확률 : 0.6734
# 실제 : dog / 예측 : dog / 확률 : 0.6893
# 실제 : dog / 예측 : dog / 확률 : 0.8196
# 실제 : dog / 예측 : dog / 확률 : 0.5502
# 실제 : dog / 예측 : dog / 확률 : 0.7183
# 실제 : dog / 예측 : dog / 확률 : 0.8122
# 실제 : dog / 예측 : dog / 확률 : 0.6705
# 실제 : dog / 예측 : dog / 확률 : 0.7331
# 실제 : dog / 예측 : dog / 확률 : 0.9000
# 실제 : dog / 예측 : dog / 확률 : 0.9178
# 실제 : dog / 예측 : dog / 확률 : 0.7959
# 실제 : dog / 예측 : dog / 확률 : 0.7551
# 실제 : dog / 예측 : dog / 확률 : 0.5950
# 실제 : dog / 예측 : dog / 확률 : 0.5761
# 실제 : dog / 예측 : dog / 확률 : 0.5737
# 실제 : dog / 예측 : dog / 확률 : 0.5380
# 실제 : dog / 예측 : dog / 확률 : 0.5967
# 실제 : dog / 예측 : dog / 확률 : 0.5822
# 실제 : dog / 예측 : dog / 확률 : 0.8070
# 실제 : dog / 예측 : cat / 확률 : 0.5249
# 실제 : dog / 예측 : dog / 확률 : 0.7636
# 실제 : dog / 예측 : dog / 확률 : 0.4743
# 실제 : dog / 예측 : dog / 확률 : 0.5582
# 실제 : dog / 예측 : dog / 확률 : 0.4212
# 실제 : dog / 예측 : dog / 확률 : 0.8021
# 실제 : dog / 예측 : dog / 확률 : 0.5791
# 실제 : dog / 예측 : dog / 확률 : 0.5779
# 실제 : dog / 예측 : dog / 확률 : 0.6681
# 실제 : dog / 예측 : dog / 확률 : 0.5043
# 실제 : dog / 예측 : dog / 확률 : 0.8544
# 실제 : dog / 예측 : dog / 확률 : 0.7634
# 실제 : dog / 예측 : dog / 확률 : 0.8271
# 실제 : dog / 예측 : dog / 확률 : 0.7992
# 실제 : dog / 예측 : dog / 확률 : 0.9014
# 실제 : dog / 예측 : dog / 확률 : 0.8683
# 실제 : dog / 예측 : dog / 확률 : 0.9061
# 실제 : dog / 예측 : dog / 확률 : 0.5908
# 실제 : dog / 예측 : dog / 확률 : 0.8742
# 실제 : dog / 예측 : cat / 확률 : 0.4977
# 실제 : dog / 예측 : dog / 확률 : 0.8699
# 실제 : dog / 예측 : dog / 확률 : 0.5733
# 실제 : dog / 예측 : dog / 확률 : 0.7321
# 실제 : dog / 예측 : dog / 확률 : 0.7091
# 실제 : dog / 예측 : dog / 확률 : 0.8443
# 실제 : dog / 예측 : dog / 확률 : 0.6469
# 실제 : dog / 예측 : dog / 확률 : 0.6020
# 실제 : dog / 예측 : dog / 확률 : 0.7861
# 실제 : dog / 예측 : dog / 확률 : 0.7409
# 실제 : dog / 예측 : dog / 확률 : 0.4877
# 실제 : dog / 예측 : dog / 확률 : 0.8173
# 실제 : dog / 예측 : dog / 확률 : 0.8649
# 실제 : dog / 예측 : dog / 확률 : 0.6076
# 실제 : dog / 예측 : dog / 확률 : 0.8256
# 실제 : dog / 예측 : dog / 확률 : 0.7592
# 실제 : dog / 예측 : dog / 확률 : 0.5190
# 실제 : dog / 예측 : dog / 확률 : 0.6596
# 실제 : dog / 예측 : dog / 확률 : 0.8695
# 실제 : dog / 예측 : dog / 확률 : 0.8098
# 실제 : dog / 예측 : dog / 확률 : 0.9192
# 실제 : dog / 예측 : cat / 확률 : 0.4362
# 실제 : dog / 예측 : dog / 확률 : 0.4660
# 실제 : dog / 예측 : dog / 확률 : 0.8816
# 실제 : dog / 예측 : dog / 확률 : 0.3749
# 실제 : dog / 예측 : dog / 확률 : 0.8487
# 실제 : dog / 예측 : dog / 확률 : 0.6498
# 실제 : dog / 예측 : cat / 확률 : 0.4698
# 실제 : dog / 예측 : dog / 확률 : 0.5213
# 실제 : dog / 예측 : dog / 확률 : 0.6065
# 실제 : dog / 예측 : dog / 확률 : 0.8997
# 실제 : dog / 예측 : dog / 확률 : 0.7867
# 실제 : dog / 예측 : dog / 확률 : 0.6716
# 실제 : dog / 예측 : dog / 확률 : 0.8832
# 실제 : dog / 예측 : cat / 확률 : 0.5215
# 실제 : dog / 예측 : dog / 확률 : 0.4340
# 실제 : dog / 예측 : dog / 확률 : 0.7973
# 실제 : dog / 예측 : dog / 확률 : 0.8848
# 실제 : dog / 예측 : dog / 확률 : 0.8225

# %% [markdown]
# ### 10. 시각화

# %%
# images, labels = next(iter(test_loader))
batch_size = 8
all_batches = list(test_loader)
images, labels = all_batches[14]  

model.eval()

with torch.no_grad():
    outputs = model(images.to(device))

    prob = torch.softmax(outputs, dim=1)
    confidence, predict = torch.max(prob, 1)

plt.figure(figsize=(12, 6))

for i in range(min(8, len(images))):
    image = images[i].permute(1, 2, 0).numpy() 

    true_label = class_names[labels[i].item()]
    pred_label = class_names[predict[i].item()]

    conf = confidence[i].item()

    # 2행 4열 형태로 이미지출력
    plt.subplot(2, 4, i+ 1)
    plt.imshow(image)
    plt.title(f'True : {true_label} / Pred : {pred_label} / Acc : {conf:.2f}')
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9295317..2.2565577].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.465708].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.5005665].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.465708].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0665298..2.2489083].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1007793..2.3262744].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8606442..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
